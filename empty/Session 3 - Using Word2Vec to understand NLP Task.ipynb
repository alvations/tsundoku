# %%
# !pip install tsundoku

# %%
# !pip install sklearn torch tqdm nltk lazyme ansi requests gensim
# !python -m nltk.downloader movie_reviews punkt

# %%
from IPython.display import display, Markdown, Latex
from tsundoku.word2vec_hints import *

# %% [markdown]
# # Overview
#
#
# - <a href="#section-3-0">**3.0. Data Preparation**</a>
#   - <a href="#section-3-0-1">3.0.1. *Vocabulary*</a>
#     - <a href="#section-3-0-1-a"> Pet Peeve: using `gensim`</a>
#   - <a href="#section-3-0-2">3.0.2. *Dataset*</a>  (<a href="#section-3-0-2-hints">Hints</a>)
#     - <a href="#section-3-0-2-return-dict">Return `dict` in `__getitem__()`</a>
#     - <a href="#section-3-0-2-labeleddata">Try `LabeledDataset`</a>
# <br><br>
# - <a href="#section-3-1">**3.1. Word2Vec from Scratch**</a>
#   - <a href="#section-3-1-1">3.1.1. *CBOW*</a>
#   - <a href="#section-3-1-2">3.1.2. *Skipgram*</a>
#   - <a href="#section-3-1-3">3.1.3. *Word2Vec Dataset*</a> (<a href="#section-3-1-3-hint">Hints</a>)
#   - <a href="#section-3-1-4-hint">3.1.4. *Train a CBOW model*</a>
#     - <a href="#section-3-1-4-fill-cbow">The CBOW model</a>
#     - <a href="#section-3-1-4-train-cbow">Train the model (*for real*)</a>
#     - <a href="#section-3-1-4-evaluate-cbow">Evaluate the model</a>
#     - <a href="#section-3-1-4-load-model">Load model at specific epoch</a>
#   - <a href="#section-3-1-5">3.1.5. *Train a Skipgram model*</a>
#     - <a href="#section-3-1-5-forward">Take a closer look at `forward()`</a>
#     - <a href="#section-3-1-5-train">Train the model (*for real*)</a>
#     - <a href="section-3-1-5-evaluate">Evaluate the model</a>
#   - <a href="#section-3-1-6">3.1.6. *Loading Pre-trained Embeddings*</a>
#     - <a href="#section-3-1-6-vocab">Override the Embedding vocabulary</a>
#     - <a href="#section-3-1-6-pretrained">Override the Embedding weights</a>
#     - <a href="#section-3-1-6-eval-skipgram">Evaluate on the Skipgram task</a>
#     - <a href="#section-3-1-6-eval-cbow">Evaluate on the CBOW task</a>
#     - <a href="#section-3-1-6-unfreeze-finetune">Unfreeeze and finetune</a>
#     - <a href="#section-3-1-6-reval-cbow">Re-evaluate on the CBOW task</a>
# <br><br>

# %% [markdown]
# <a id="section-3-0"></a>
# # 3.0. Data Preparation
#
# Before we train our own embeddings, lets first understand how to read text data into pytorch.
# The native pytorch way to load datasets is to use the `torch.utils.data.Dataset` object.
#
# There are already several other libraries that help with loading text datasets, e.g.
#
#  - FastAI https://docs.fast.ai/text.data.html
#  - AllenNLP https://allenai.github.io/allennlp-docs/api/allennlp.data.dataset.html
#  - Torch Text https://github.com/pytorch/text#data
#  - Texar https://texar.readthedocs.io/en/latest/code/data.html#id4
#  - SpaCy https://github.com/explosion/thinc
#
#
# But to truly understand and use it for the custom datasets you'll see at work, lets learn it the native way.

# %% [markdown]
# <a id="section-3-0-1"></a>
# ## 3.0.1  Vocabulary
#
# Given a text, the first thing to do is to build a vocabulary (i.e. a dictionary of unique words) and assign an index to each unique word.

# %%
import random
from itertools import chain

from tqdm import tqdm
from gensim.corpora import Dictionary

import torch
from torch import nn, optim, tensor, autograd
from torch.nn import functional as F
from torch.utils.data import Dataset
import numpy as np

from functools import partial
from torch.utils.data import Dataset, DataLoader
from torch import functional as F

# %%
try: # Use the default NLTK tokenizer.
    from nltk import word_tokenize, sent_tokenize 
    # Testing whether it works. 
    # Sometimes it doesn't work on some machines because of setup issues.
    word_tokenize(sent_tokenize("This is a foobar sentence. Yes it is.")[0])
except: # Use a naive sentence tokenizer and toktok.
    import re
    from nltk.tokenize import ToktokTokenizer
    # See https://stackoverflow.com/a/25736515/610569
    sent_tokenize = lambda x: re.split(r'(?<=[^A-Z].[.?]) +(?=[A-Z])', x)
    # Use the toktok tokenizer that requires no dependencies.
    toktok = ToktokTokenizer()
    word_tokenize = word_tokenize = toktok.tokenize

# %%
text = """Language users never choose words randomly, and language is essentially
non-random. Statistical hypothesis testing uses a null hypothesis, which
posits randomness. Hence, when we look at linguistic phenomena in corpora, 
the null hypothesis will never be true. Moreover, where there is enough
data, we shall (almost) always be able to establish that it is not true. In
corpus studies, we frequently do have enough data, so the fact that a relation 
between two phenomena is demonstrably non-random, does not support the inference 
that it is not arbitrary. We present experimental evidence
of how arbitrary associations between word frequencies and corpora are
systematically non-random. We review literature in which hypothesis testing 
has been used, and show how it has often led to unhelpful or misleading results.""".lower()

tokenized_text = [word_tokenize(sent) for sent in sent_tokenize(text)]

uniq_tokens = set(chain(*tokenized_text))

vocab = {}   # Assign indices to every word.
idx2tok = {} # Also keep an dict of index to words.
for i, token in enumerate(uniq_tokens):
    vocab[token] = i
    idx2tok[i] = token

# %%
vocab
# Out:
# {'corpora': 0,
#  'corpus': 1,
#  '.': 2,
#  'unhelpful': 3,
#  'relation': 4,
#  'it': 5,
#  'never': 6,
#  'the': 7,
#  'not': 8,
#  'used': 9,
#  'and': 10,
#  'hypothesis': 11,
#  'support': 12,
#  'linguistic': 13,
#  'language': 14,
#  'which': 15,
#  'will': 16,
#  'in': 17,
#  'true': 18,
#  'words': 19,
#  'experimental': 20,
#  'of': 21,
#  'always': 22,
#  'null': 23,
#  'associations': 24,
#  'or': 25,
#  '(': 26,
#  'able': 27,
#  'been': 28,
#  'show': 29,
#  'how': 30,
#  'choose': 31,
#  'often': 32,
#  'frequencies': 33,
#  'misleading': 34,
#  'do': 35,
#  'has': 36,
#  'led': 37,
#  'non-random': 38,
#  'randomness': 39,
#  'data': 40,
#  'does': 41,
#  'where': 42,
#  'inference': 43,
#  'shall': 44,
#  'demonstrably': 45,
#  'that': 46,
#  'there': 47,
#  'users': 48,
#  'establish': 49,
#  'at': 50,
#  'testing': 51,
#  'two': 52,
#  'studies': 53,
#  'hence': 54,
#  'literature': 55,
#  'so': 56,
#  'systematically': 57,
#  ')': 58,
#  'we': 59,
#  ',': 60,
#  'arbitrary': 61,
#  'look': 62,
#  'enough': 63,
#  'essentially': 64,
#  'uses': 65,
#  'statistical': 66,
#  'when': 67,
#  'almost': 68,
#  'moreover': 69,
#  'to': 70,
#  'fact': 71,
#  'between': 72,
#  'have': 73,
#  'posits': 74,
#  'phenomena': 75,
#  'be': 76,
#  'word': 77,
#  'results': 78,
#  'randomly': 79,
#  'frequently': 80,
#  'evidence': 81,
#  'present': 82,
#  'is': 83,
#  'a': 84,
#  'are': 85,
#  'review': 86}

# %%
# Retrieve the index of the word 'corpora'
vocab['non-random']
# Out:
# 38

# %%
# The indexed representation of the first sentence.

sent0 = tokenized_text[0]

[vocab[token] for token in sent0]
# Out:
# [14, 48, 6, 31, 19, 79, 60, 10, 14, 83, 64, 38, 2]

# %% [markdown]
# <a id="section-3-0-1-a"></a>
#
# ### Pet Peeve (Gensim)
#
# I (Liling) don't really like to write my own vectorizer the `gensim` has functions that are optimized for such operations. In fact, I've written a [whole preprocessing pipeline library for me to use for language modelling and machine translation purposes](https://github.com/alvations/komorebi/blob/master/komorebi/text.py) =)
#
# Using `gensim`, I would have written the above as such:

# %%
from gensim.corpora.dictionary import Dictionary
vocab = Dictionary(tokenized_text)

# %%
# Note the key-value order is different of gensim from the native Python's
dict(vocab.items())
# Out:
# {0: ',',
#  1: '.',
#  2: 'and',
#  3: 'choose',
#  4: 'essentially',
#  5: 'is',
#  6: 'language',
#  7: 'never',
#  8: 'non-random',
#  9: 'randomly',
#  10: 'users',
#  11: 'words',
#  12: 'a',
#  13: 'hypothesis',
#  14: 'null',
#  15: 'posits',
#  16: 'randomness',
#  17: 'statistical',
#  18: 'testing',
#  19: 'uses',
#  20: 'which',
#  21: 'at',
#  22: 'be',
#  23: 'corpora',
#  24: 'hence',
#  25: 'in',
#  26: 'linguistic',
#  27: 'look',
#  28: 'phenomena',
#  29: 'the',
#  30: 'true',
#  31: 'we',
#  32: 'when',
#  33: 'will',
#  34: '(',
#  35: ')',
#  36: 'able',
#  37: 'almost',
#  38: 'always',
#  39: 'data',
#  40: 'enough',
#  41: 'establish',
#  42: 'it',
#  43: 'moreover',
#  44: 'not',
#  45: 'shall',
#  46: 'that',
#  47: 'there',
#  48: 'to',
#  49: 'where',
#  50: 'arbitrary',
#  51: 'between',
#  52: 'corpus',
#  53: 'demonstrably',
#  54: 'do',
#  55: 'does',
#  56: 'fact',
#  57: 'frequently',
#  58: 'have',
#  59: 'inference',
#  60: 'relation',
#  61: 'so',
#  62: 'studies',
#  63: 'support',
#  64: 'two',
#  65: 'are',
#  66: 'associations',
#  67: 'evidence',
#  68: 'experimental',
#  69: 'frequencies',
#  70: 'how',
#  71: 'of',
#  72: 'present',
#  73: 'systematically',
#  74: 'word',
#  75: 'been',
#  76: 'has',
#  77: 'led',
#  78: 'literature',
#  79: 'misleading',
#  80: 'often',
#  81: 'or',
#  82: 'results',
#  83: 'review',
#  84: 'show',
#  85: 'unhelpful',
#  86: 'used'}

# %%
vocab.token2id['corpora']
# Out:
# 23

# %%
vocab.doc2idx(sent0)
# Out:
# [6, 10, 7, 3, 11, 9, 0, 2, 6, 5, 4, 8, 1]

# %% [markdown]
# The "indexed form" of the tokens in the sentence forms the ***vectorized*** input to the `nn.Embedding` layer in PyTorch.

# %% [markdown]
# <a id="section-3-0-2"></a>
#
# # 3.0.2 Dataset
#
# Lets try creating a `torch.utils.data.Dataset` object.

# %%
from torch.utils.data import Dataset, DataLoader

class Text(Dataset):
    def __init__(self, tokenized_texts):
        """
        :param tokenized_texts: Tokenized text.
        :type tokenized_texts: list(list(str))
        """
        self.sents = tokenized_texts
        self.vocab = Dictionary(tokenized_texts)

    def __getitem__(self, index):
        """
        The primary entry point for PyTorch datasets.
        This is were you access the specific data row you want.
        
        :param index: Index to the data point.
        :type index: int
        """
        # Hint: You want to return a vectorized sentence here.
        return {'x': self.???}

    def vectorize(self, tokens):
        """
        :param tokens: Tokens that should be vectorized. 
        :type tokens: list(str)
        """
        # See https://radimrehurek.com/gensim/corpora/dictionary.html#gensim.corpora.dictionary.Dictionary.doc2idx 
        return self.???
    
    def unvectorize(self, indices):
        """
        :param indices: Converts the indices back to tokens.
        :type tokens: list(int)
        """
        return [self.vocab[i] for i in indices]

# %% [markdown]
# <a id="section-3-0-2-hints"></a>
# ## Hints to the above cell

# %%
# Option 1: To see the hint and partial code for the cell above, uncomment the following line.
##hint_dataset_vectorize()
##code_text_dataset_vectorize()

# Option 2: "I give up just, run the code for me" 
# Uncomment the next two lines, if you really gave up... 
#full_code_text_dataset_vectorize()
#from tsundoku.word2vec import Text

# %%
tokenized_text[5]
# Out:
# ['we',
#  'present',
#  'experimental',
#  'evidence',
#  'of',
#  'how',
#  'arbitrary',
#  'associations',
#  'between',
#  'word',
#  'frequencies',
#  'and',
#  'corpora',
#  'are',
#  'systematically',
#  'non-random',
#  '.']

# %%
text_dataset = Text(tokenized_text)

# %%
text_dataset[5] # First sentence.
# Out:
# {'x': [31, 72, 68, 67, 71, 70, 50, 66, 51, 74, 69, 2, 23, 65, 73, 8, 1]}

# %% [markdown]
# <a id="section-3-0-2-return-dict"></a>
#
# ### Return `dict` in `__getitem__()`
#
# This is nice if we're just representing sentences/documents by their indices but when we're doing machine learning, we usually have `X` and `Y`.
#
# If we have labels for the each sentence, we can also put it into to `__getitem__()` by having it return a dictionary.

# %%
from torch.utils.data import Dataset, DataLoader

class LabeledText(Dataset):
    def __init__(self, tokenized_texts, labels):
        """
        :param tokenized_texts: Tokenized text.
        :type tokenized_texts: list(list(str))
        """
        self.sents = tokenized_texts
        self.labels = labels # Sentence level labels.
        self.vocab = Dictionary(self.sents)

    def __getitem__(self, index):
        """
        The primary entry point for PyTorch datasets.
        This is were you access the specific data row you want.
        
        :param index: Index to the data point.
        :type index: int
        """
        return {'x': self.vectorize(self.sents[index]), 'y': self.labels[index]}

    def vectorize(self, tokens):
        """
        :param tokens: Tokens that should be vectorized. 
        :type tokens: list(str)
        """
        # See https://radimrehurek.com/gensim/corpora/dictionary.html#gensim.corpora.dictionary.Dictionary.doc2idx 
        return self.vocab.doc2idx(tokens)
    
    def unvectorize(self, indices):
        """
        :param indices: Converts the indices back to tokens.
        :type tokens: list(int)
        """
        return [self.vocab[i] for i in indices]

# %% [markdown]
# <a id="section-3-0-2-labeleddata"></a>
#
# ### Lets try the `LabeledDataset` on a movie review corpus

# %%
from nltk.corpus import movie_reviews

# %%
documents = []
labels = []

for fileid in tqdm(movie_reviews.fileids()):
    label = fileid.split('/')[0]
    doc = word_tokenize(movie_reviews.open(fileid).read())
    documents.append(doc)
    labels.append(label)
# Out:
# 100%|██████████| 2000/2000 [00:14<00:00, 139.99it/s]

# %%
print(documents[0])
# Out:
# ['plot', ':', 'two', 'teen', 'couples', 'go', 'to', 'a', 'church', 'party', ',', 'drink', 'and', 'then', 'drive', '.', 'they', 'get', 'into', 'an', 'accident', '.', 'one', 'of', 'the', 'guys', 'dies', ',', 'but', 'his', 'girlfriend', 'continues', 'to', 'see', 'him', 'in', 'her', 'life', ',', 'and', 'has', 'nightmares', '.', 'what', "'s", 'the', 'deal', '?', 'watch', 'the', 'movie', 'and', '``', 'sorta', '``', 'find', 'out', '.', '.', '.', 'critique', ':', 'a', 'mind-fuck', 'movie', 'for', 'the', 'teen', 'generation', 'that', 'touches', 'on', 'a', 'very', 'cool', 'idea', ',', 'but', 'presents', 'it', 'in', 'a', 'very', 'bad', 'package', '.', 'which', 'is', 'what', 'makes', 'this', 'review', 'an', 'even', 'harder', 'one', 'to', 'write', ',', 'since', 'i', 'generally', 'applaud', 'films', 'which', 'attempt', 'to', 'break', 'the', 'mold', ',', 'mess', 'with', 'your', 'head', 'and', 'such', '(', 'lost', 'highway', '&', 'memento', ')', ',', 'but', 'there', 'are', 'good', 'and', 'bad', 'ways', 'of', 'making', 'all', 'types', 'of', 'films', ',', 'and', 'these', 'folks', 'just', 'did', "n't", 'snag', 'this', 'one', 'correctly', '.', 'they', 'seem', 'to', 'have', 'taken', 'this', 'pretty', 'neat', 'concept', ',', 'but', 'executed', 'it', 'terribly', '.', 'so', 'what', 'are', 'the', 'problems', 'with', 'the', 'movie', '?', 'well', ',', 'its', 'main', 'problem', 'is', 'that', 'it', "'s", 'simply', 'too', 'jumbled', '.', 'it', 'starts', 'off', '``', 'normal', '``', 'but', 'then', 'downshifts', 'into', 'this', '``', 'fantasy', '``', 'world', 'in', 'which', 'you', ',', 'as', 'an', 'audience', 'member', ',', 'have', 'no', 'idea', 'what', "'s", 'going', 'on', '.', 'there', 'are', 'dreams', ',', 'there', 'are', 'characters', 'coming', 'back', 'from', 'the', 'dead', ',', 'there', 'are', 'others', 'who', 'look', 'like', 'the', 'dead', ',', 'there', 'are', 'strange', 'apparitions', ',', 'there', 'are', 'disappearances', ',', 'there', 'are', 'a', 'looooot', 'of', 'chase', 'scenes', ',', 'there', 'are', 'tons', 'of', 'weird', 'things', 'that', 'happen', ',', 'and', 'most', 'of', 'it', 'is', 'simply', 'not', 'explained', '.', 'now', 'i', 'personally', 'do', "n't", 'mind', 'trying', 'to', 'unravel', 'a', 'film', 'every', 'now', 'and', 'then', ',', 'but', 'when', 'all', 'it', 'does', 'is', 'give', 'me', 'the', 'same', 'clue', 'over', 'and', 'over', 'again', ',', 'i', 'get', 'kind', 'of', 'fed', 'up', 'after', 'a', 'while', ',', 'which', 'is', 'this', 'film', "'s", 'biggest', 'problem', '.', 'it', "'s", 'obviously', 'got', 'this', 'big', 'secret', 'to', 'hide', ',', 'but', 'it', 'seems', 'to', 'want', 'to', 'hide', 'it', 'completely', 'until', 'its', 'final', 'five', 'minutes', '.', 'and', 'do', 'they', 'make', 'things', 'entertaining', ',', 'thrilling', 'or', 'even', 'engaging', ',', 'in', 'the', 'meantime', '?', 'not', 'really', '.', 'the', 'sad', 'part', 'is', 'that', 'the', 'arrow', 'and', 'i', 'both', 'dig', 'on', 'flicks', 'like', 'this', ',', 'so', 'we', 'actually', 'figured', 'most', 'of', 'it', 'out', 'by', 'the', 'half-way', 'point', ',', 'so', 'all', 'of', 'the', 'strangeness', 'after', 'that', 'did', 'start', 'to', 'make', 'a', 'little', 'bit', 'of', 'sense', ',', 'but', 'it', 'still', 'did', "n't", 'the', 'make', 'the', 'film', 'all', 'that', 'more', 'entertaining', '.', 'i', 'guess', 'the', 'bottom', 'line', 'with', 'movies', 'like', 'this', 'is', 'that', 'you', 'should', 'always', 'make', 'sure', 'that', 'the', 'audience', 'is', '``', 'into', 'it', '``', 'even', 'before', 'they', 'are', 'given', 'the', 'secret', 'password', 'to', 'enter', 'your', 'world', 'of', 'understanding', '.', 'i', 'mean', ',', 'showing', 'melissa', 'sagemiller', 'running', 'away', 'from', 'visions', 'for', 'about', '20', 'minutes', 'throughout', 'the', 'movie', 'is', 'just', 'plain', 'lazy', '!', '!', 'okay', ',', 'we', 'get', 'it', '.', '.', '.', 'there', 'are', 'people', 'chasing', 'her', 'and', 'we', 'do', "n't", 'know', 'who', 'they', 'are', '.', 'do', 'we', 'r ...

# %%
labeled_dataset = LabeledText(documents, labels)

# %%
print(labeled_dataset[0])  # First review in the data.
# Out:
# {'X': [243, 17, 314, 294, 77, 140, 307, 20, 68, 237, 6, 97, 34, 299, 98, 8, 302, 135, 167, 33, 22, 8, 226, 220, 297, 145, 87, 6, 60, 158, 136, 74, 307, 262, 157, 165, 153, 179, 6, 34, 149, 214, 8, 333, 2, 297, 82, 18, 326, 297, 204, 34, 19, 280, 19, 124, 230, 8, 8, 8, 79, 17, 20, 199, 204, 129, 297, 294, 133, 296, 311, 225, 20, 322, 75, 164, 6, 60, 245, 169, 165, 20, 322, 46, 234, 8, 337, 168, 333, 188, 304, 253, 33, 108, 148, 226, 307, 345, 6, 272, 163, 132, 37, 122, 337, 42, 307, 59, 297, 201, 6, 196, 341, 348, 152, 34, 290, 4, 185, 156, 1, 195, 5, 6, 60, 300, 38, 142, 34, 46, 328, 220, 189, 28, 315, 220, 122, 6, 34, 301, 128, 173, 86, 208, 276, 304, 226, 76, 8, 302, 263, 307, 150, 293, 304, 246, 209, 72, 6, 60, 113, 169, 295, 8, 277, 333, 38, 297, 248, 341, 297, 204, 18, 331, 6, 170, 186, 247, 168, 296, 169, 2, 271, 309, 172, 8, 169, 282, 221, 19, 216, 19, 60, 299, 95, 167, 304, 19, 116, 19, 342, 165, 337, 347, 6, 40, 33, 43, 194, 6, 150, 215, 164, 333, 2, 141, 225, 8, 300, 38, 96, 6, 300, 38, 64, 70, 45, 130, 297, 81, 6, 300, 38, 229, 339, 183, 180, 297, 81, 6, 300, 38, 286, 36, 6, 300, 38, 91, 6, 300, 38, 20, 184, 220, 65, 260, 6, 300, 38, 308, 220, 330, 303, 296, 147, 6, 34, 203, 220, 169, 168, 271, 217, 114, 8, 218, 163, 240, 92, 208, 198, 312, 307, 317, 
348, 342, 220, 316, 8, 163, 191, 6, 269, 193, 257, 254, 44, 130, 324, 129, 21, 11, 200, 306, 297, 204, 168, 173, 241, 178, 0, 0, 224, 6, 329, 135, 169, 8, 8, 8, 300, 38, 239, 66, 153, 34, 329, 92, 208, 176, 339, 302, 38, 8, 92, 329, 251, 210, 307, 262, 169, 231, 34, 231, 26, 18, 162, 21, 139, 321, 88, 260, 222, 131, 166, 167, 28, 220, 297, 287, 141, 94, 165, 297, 204, 18, 35, 6, 297, 289, 310, 304, 121, 44, 130, 170, 90, 34, 67, 169, 320, 298, 6, 34, 169, 270, 8, 300, 197, 3, 50, 20, 246, 83, 294, 199, 204, 165, 154, 279, 6, 60, 163, 144, 19, 297, 291, 19, 84, 296, 313, 169, 167, 20, 206, 323, 341, 182, 100, 6, 343, 187, 202, 266, 8, 297, 23, 38, 246, 142, 129, 297, 203, 236, 6, 30, 332, 52, 173, 264, 307, 47, 242, 297, 111, 259, 63, 296, 151, 86, 165, 32, 48, 6, 227, 165, 20, 212, 211, 8, 60, 207, 54, 177, 140, 230, 307, 257, 6, 339, 159, 153, 233, 306, 297, 107, 121, 6, 34, 24, 149, 347, 118, 153, 63, 2, 318, 8, 232, 6, 297, 121, 93, 208, 283, 49, 169, 93, 208, 105, 6, 169, 2, 73, 6, 169, 250, 112, 34, 169, 119, 246, 252, 129, 203, 220, 170, 255, 6, 85, 20, 246, 75, 102, 34, 115, 307, 28, 220, 297, 78, 296, 62, 51, 169, 8, 223, 6, 34, 61, 297, 327, 6, 304, 168, 217, 20, 160, 228, 294, 275, 126, 8, 8, 8, 169, 2, 173, 235, 307, 183, 296, 327, 49, 278, 168, 35, 41, 296, 297, 134, 168, 284, 161, 341, 297, 174, 8, 169, 29, 344, 249, 314, 346, 27, 34, 149, 50, 273, 225, 297, 267, 109, 272, 8, 334, 8, 8, 8, 274, 169, 0, 336, 2, 171, 70, 130, 18, 20, 213, 220, 101, 288, 12, 4, 14, 5, 7, 56, 340, 10, 4, 14, 5, 7, 297, 80, 4, 16, 5, 7, 297, 80, 17, 258, 4, 13, 5, 7, 185, 156, 4, 9, 5, 7, 195, 4, 9, 5, 7, 297, 229, 4, 16, 5, 7, 285, 220, 99, 4, 15, 5]

# %%
print(labeled_dataset[0]['y'])  # Label of the first review in the data.
# Out:
# neg

# %% [markdown]
# <a id="section-3-1"></a>
#
# # 3.1 Word2Vec Training
#
# Word2Vec has two training variants:
#
#  - **Continuous Bag of Words (CBOW)**: Predict center word from (bag of) context words.
#  - **Skip-grams**: Predict context words given center word.
#
# Visually, they look like this:
#
#
#
# <img src="https://lilianweng.github.io/lil-log/assets/images/word2vec-cbow.png" width="500" align="left">

# %% [markdown]
# Fig. 1. The skip-gram model. Both the input vector xx and the output yy are one-hot encoded word representations. <br>The hidden layer is the word embedding of size NN.

# %% [markdown]
# <img src="https://lilianweng.github.io/lil-log/assets/images/word2vec-skip-gram.png" width="500" align="left">

# %% [markdown]
# Fig. 2. The CBOW model. Word vectors of multiple context words are averaged to get a fixed-length vector as in the hidden layer. Other symbols have the same meanings as in Fig 1.
#
# (Pretty network images above are from [https://lilianweng.github.io](https://lilianweng.github.io/lil-log/2017/10/15/learning-word-embedding.html#context-based-continuous-bag-of-words-cbow))

# %% [markdown]
# <a id="section-3-1-1"></a>
#
# ## 3.1.1. CBOW
#
# CBOW windows through the sentence and picks out the center word as the `Y` and the surrounding context words as the inputs `X`.

# %%
from lazyme import per_window, per_chunk

xx =[1,2,3,4]
list(per_window(xx, n=2))
list(per_chunk(xx, n=3))
# Out:
# [(1, 2, 3), (4, None, None)]

# %%
def per_window(sequence, n=1):
    """
    From http://stackoverflow.com/q/42220614/610569
        >>> list(per_window([1,2,3,4], n=2))
        [(1, 2), (2, 3), (3, 4)]
        >>> list(per_window([1,2,3,4], n=3))
        [(1, 2, 3), (2, 3, 4)]
    """
    start, stop = 0, n
    seq = list(sequence)
    while stop <= len(seq):
        yield seq[start:stop]
        start += 1
        stop += 1

def cbow_iterator(tokens, window_size):
    n = window_size * 2 + 1
    for window in per_window(tokens, n):
        target = window.pop(window_size)
        yield window, target   # X = window ; Y = target.

# %%
sent0 = ['language', 'users', 'never', 'choose', 'words', 'randomly', ',', 
         'and', 'language', 'is', 'essentially', 'non-random', '.']

# %%
list(cbow_iterator(sent0, 2))
# Out:
# [(['language', 'users', 'choose', 'words'], 'never'),
#  (['users', 'never', 'words', 'randomly'], 'choose'),
#  (['never', 'choose', 'randomly', ','], 'words'),
#  (['choose', 'words', ',', 'and'], 'randomly'),
#  (['words', 'randomly', 'and', 'language'], ','),
#  (['randomly', ',', 'language', 'is'], 'and'),
#  ([',', 'and', 'is', 'essentially'], 'language'),
#  (['and', 'language', 'essentially', 'non-random'], 'is'),
#  (['language', 'is', 'non-random', '.'], 'essentially')]

# %%
list(cbow_iterator(sent0, 3))
# Out:
# [(['language', 'users', 'never', 'words', 'randomly', ','], 'choose'),
#  (['users', 'never', 'choose', 'randomly', ',', 'and'], 'words'),
#  (['never', 'choose', 'words', ',', 'and', 'language'], 'randomly'),
#  (['choose', 'words', 'randomly', 'and', 'language', 'is'], ','),
#  (['words', 'randomly', ',', 'language', 'is', 'essentially'], 'and'),
#  (['randomly', ',', 'and', 'is', 'essentially', 'non-random'], 'language'),
#  ([',', 'and', 'language', 'essentially', 'non-random', '.'], 'is')]

# %% [markdown]
# <a id="section-3-1-2"></a>
#
# ## 3.1.2. Skipgram
#
# Skipgram training windows through the sentence and pictures out the center word as the input `X` and the context words as the outputs `Y`, additionally, it will randommly sample words not in the window as **negative samples**.

# %%
def skipgram_iterator(tokens, window_size):
    n = window_size * 2 + 1 
    for i, window in enumerate(per_window(tokens, n)):
        target = window.pop(window_size)
        # Generate positive samples.
        for context_word in window:
            yield target, context_word, 1
        # Generate negative samples.
        for _ in range(n-1):
            leftovers = tokens[:i] + tokens[i+n:]
            yield target, random.choice(leftovers), 0

# %%
list(skipgram_iterator(sent0, 2))
# Out:
# [('never', 'language', 1),
#  ('never', 'users', 1),
#  ('never', 'choose', 1),
#  ('never', 'words', 1),
#  ('never', '.', 0),
#  ('never', 'non-random', 0),
#  ('never', 'non-random', 0),
#  ('never', 'language', 0),
#  ('choose', 'users', 1),
#  ('choose', 'never', 1),
#  ('choose', 'words', 1),
#  ('choose', 'randomly', 1),
#  ('choose', '.', 0),
#  ('choose', 'language', 0),
#  ('choose', 'essentially', 0),
#  ('choose', 'is', 0),
#  ('words', 'never', 1),
#  ('words', 'choose', 1),
#  ('words', 'randomly', 1),
#  ('words', ',', 1),
#  ('words', 'language', 0),
#  ('words', 'language', 0),
#  ('words', 'is', 0),
#  ('words', 'and', 0),
#  ('randomly', 'choose', 1),
#  ('randomly', 'words', 1),
#  ('randomly', ',', 1),
#  ('randomly', 'and', 1),
#  ('randomly', 'never', 0),
#  ('randomly', 'non-random', 0),
#  ('randomly', 'is', 0),
#  ('randomly', 'non-random', 0),
#  (',', 'words', 1),
#  (',', 'randomly', 1),
#  (',', 'and', 1),
#  (',', 'language', 1),
#  (',', 'essentially', 0),
#  (',', 'essentially', 0),
#  (',', 'non-random', 0),
#  (',', 'non-random', 0),
#  ('and', 'randomly', 1),
#  ('and', ',', 1),
#  ('and', 'language', 1),
#  ('and', 'is', 1),
#  ('and', 'essentially', 0),
#  ('and', 'users', 0),
#  ('and', 'users', 0),
#  ('and', 'essentially', 0),
#  ('language', ',', 1),
#  ('language', 'and', 1),
#  ('language', 'is', 1),
#  ('language', 'essentially', 1),
#  ('language', 'users', 0),
#  ('language', 'randomly', 0),
#  ('language', 'never', 0),
#  ('language', 'words', 0),
#  ('is', 'and', 1),
#  ('is', 'language', 1),
#  ('is', 'essentially', 1),
#  ('is', 'non-random', 1),
#  ('is', 'never', 0),
#  ('is', 'language', 0),
#  ('is', '.', 0),
#  ('is', 'never', 0),
#  ('essentially', 'language', 1),
#  ('essentially', 'is', 1),
#  ('essentially', 'non-random', 1),
#  ('essentially', '.', 1),
#  ('essentially', 'users', 0),
#  ('essentially', 'randomly', 0),
#  ('essentially', 'and', 0),
#  ('essentially', 'and', 0)]

# %% [markdown]
# ## Cut-away: What is `partial`?
#
# The [`functools.partial`](https://docs.python.org/3.7/library/functools.html#functools.partial) function in Python is a mechanism to overload a function with preset arguments.
#
# For example:

# %%
from nltk import ngrams

# Generates bigrams
list(ngrams('this is a sentence'.split(), n=2))
# Out:
# [('this', 'is'), ('is', 'a'), ('a', 'sentence')]

# %%
from functools import partial

# You can create a new function that "preset" the `n` argument, e.g.
bigrams = partial(ngrams, n=2)
trigrams = partial(ngrams, n=3)

# %%
list(trigrams('this is a sentence'.split()))
# Out:
# [('this', 'is', 'a'), ('is', 'a', 'sentence')]

# %%
list(bigrams('this is a sentence'.split()))
# Out:
# [('this', 'is'), ('is', 'a'), ('a', 'sentence')]

# %% [markdown]
# <a id="section-3-1-3"></a>
#
# ## 3.1.3 Word2Vec Dataset
#
# Now that we know what are the inputs `X` and outputs `Y` of the Word2Vec task.
#
# Lets put everything together and modify the `Dataset` so that `__getitem__` retrieves CBOW or Skipgram formats.

# %%
class Word2VecText(Dataset):
    def __init__(self, tokenized_texts, window_size, variant):
        """
        :param tokenized_texts: Tokenized text.
        :type tokenized_texts: list(list(str))
        """
        self.sents = tokenized_texts
        self._len = len(self.sents)
        self.vocab = Dictionary(self.sents)
        self.window_size = window_size
        self.variant = variant
        if variant.lower() == 'cbow':
            self._iterator = partial(self.cbow_iterator, window_size=self.window_size)
        elif variant.lower() == 'skipgram':
            self._iterator = partial(self.skipgram_iterator, window_size=self.window_size)

    def __getitem__(self, index):
        """
        The primary entry point for PyTorch datasets.
        This is were you access the specific data row you want.

        :param index: Index to the data point.
        :type index: int
        """
        vectorized_sent = self.vectorize(self.sents[index])
        return list(self._iterator(vectorized_sent))

    def __len__(self):
        return self._len

    def vectorize(self, tokens):
        """
        :param tokens: Tokens that should be vectorized.
        :type tokens: list(str)
        """
        # See https://radimrehurek.com/gensim/corpora/dictionary.html#gensim.corpora.dictionary.Dictionary.doc2idx
        return self.???(tokens)

    def unvectorize(self, indices):
        """
        :param indices: Converts the indices back to tokens.
        :type tokens: list(int)
        """
        return [self.vocab[i] for i in indices]

    def cbow_iterator(self, tokens, window_size):
        ???

    def skipgram_iterator(self, tokens, window_size):
        ???

# %% [markdown]
# <a id="section-3-1-3-hint"></a>
# ## Hints for the cell above.

# %%
# Option 1: To see the hint and partial code for the cell above, uncomment the following line.
##hint_word2vec_dataset()

# Option 2: "I give up just, run the code for me" 
# Uncomment the next two lines, if you really gave up... 
##full_code_word2vec_dataset()
##from tsundoku.word2vec import Word2VecText

# %% [markdown]
# <a id="section-3-1-4-hint"></a>
#
# ## 3.1.4. Train a CBOW model
#
# ### Lets Get Some Data
#
# Lets take Kilgarriff (2005) , "Language is never ever, ever random".

# %%
import os
import requests
import io #codecs


# Text version of https://kilgarriff.co.uk/Publications/2005-K-lineer.pdf
if os.path.isfile('language-never-random.txt'):
    with io.open('language-never-random.txt', encoding='utf8') as fin:
        text = fin.read()
else:
    url = "https://gist.githubusercontent.com/alvations/53b01e4076573fea47c6057120bb017a/raw/b01ff96a5f76848450e648f35da6497ca9454e4a/language-never-random.txt"
    text = requests.get(url).content.decode('utf8')
    with io.open('language-never-random.txt', 'w', encoding='utf8') as fout:
        fout.write(text)

tokenized_text = [list(map(str.lower, word_tokenize(sent))) for sent in sent_tokenize(text)]
window_size = 2
w2v_dataset = Word2VecText(tokenized_text, window_size=window_size, variant='cbow')

# %%
print(text[:1000])
# Out:
#                        Language is never, ever, ever, random
#
#                                                                ADAM KILGARRIFF
#
#
#
#
# Abstract
# Language users never choose words randomly, and language is essentially
# non-random. Statistical hypothesis testing uses a null hypothesis, which
# posits randomness. Hence, when we look at linguistic phenomena in cor-
# pora, the null hypothesis will never be true. Moreover, where there is enough
# data, we shall (almost) always be able to establish that it is not true. In
# corpus studies, we frequently do have enough data, so the fact that a rela-
# tion between two phenomena is demonstrably non-random, does not sup-
# port the inference that it is not arbitrary. We present experimental evidence
# of how arbitrary associations between word frequencies and corpora are
# systematically non-random. We review literature in which hypothesis test-
# ing has been used, and show how it has often led to unhelpful or mislead-
# ing results.
# Keywords: 쎲쎲쎲
#
# 1. Int

# %%
# Sanity check, lets take a look at the data.
print(tokenized_text[0])
# Out:
# ['language', 'is', 'never', ',', 'ever', ',', 'ever', ',', 'random', 'adam', 'kilgarriff', 'abstract', 'language', 'users', 'never', 'choose', 'words', 'randomly', ',', 'and', 'language', 'is', 'essentially', 'non-random', '.']

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
from lazyme import color_str

def visualize_predictions(x, y, prediction, vocab, window_size, unk='<unk>'):
    left = ' '.join([vocab.get(int(_x), '<unk>') for _x in x[:window_size]])
    right = ' '.join([vocab.get(int(_x), '<unk>') for _x in x[window_size:]])
    target = vocab.get(int(y), '<unk>')

    if not prediction:
        predicted_word = '______'
    else:
        predicted_word = vocab.get(int(prediction), '<unk>') 
    print(color_str(target, 'green'), '\t' if len(target) > 6 else '\t\t', 
          left, color_str(predicted_word, 'green' if target == predicted_word else 'red'), right)
    

sent_idx = 10
window_size = 2
w2v_dataset = Word2VecText(tokenized_text, window_size=window_size, variant='cbow')
print(' '.join(w2v_dataset.sents[sent_idx]))
for w2v_io in w2v_dataset[sent_idx]:
    context, target = w2v_io['x'], w2v_io['y']
    context, target = tensor(context).to(device), tensor(target).to(device)
    visualize_predictions(context, target, None, w2v_dataset.vocab, window_size)
# Out:
# the bulk of linguistic questions concern the dis- tinction between a and m. a linguistic account of a phenomenon gen- erally gives us reason to view the relation between , for example , a verb ’ s syntax and its semantics , as motivated rather than arbitrary .
# of 		 the bulk ______ linguistic questions
# linguistic 	 bulk of ______ questions concern
# questions 	 of linguistic ______ concern the
# concern 	 linguistic questions ______ the dis-
# the 		 questions concern ______ dis- tinction
# dis- 		 concern the ______ tinction between
# tinction 	 the dis- ______ between a
# between 	 dis- tinction ______ a and
# a 		 tinction between ______ and m.
# and 		 between a ______ m. a
# m. 		 a and ______ a linguistic
# a 		 and m. ______ linguistic account
# linguistic 	 m. a ______ account of
# account 	 a linguistic ______ of a
# of 		 linguistic account ______ a phenomenon
# a 		 account of ______ phenomenon gen-
# phenomenon 	 of a ______ gen- erally
# gen- 		 a phenomenon ______ erally gives
# erally 		 phenomenon gen- ______ gives us
# gives 		 gen- erally ______ us reason
# us 		 erally gives ______ reason to
# reason 		 gives us ______ to view
# to 		 us reason ______ view the
# view 		 reason to ______ the relation
# the 		 to view ______ relation between
# relation 	 view the ______ between ,
# between 	 the relation ______ , for
# , 		 relation between ______ for example
# for 		 between , ______ example ,
# example 	 , for ______ , a
# , 		 for example ______ a verb
# a 		 example , ______ verb ’
# verb 		 , a ______ ’ s
# ’ 		 a verb ______ s syntax
# s 		 verb ’ ______ syntax and
# syntax 		 ’ s ______ and its
# and 		 s syntax ______ its semantics
# its 		 syntax and ______ semantics ,
# semantics 	 and its ______ , as
# , 		 its semantics ______ as motivated
# as 		 semantics , ______ motivated rather
# motivated 	 , as ______ rather than
# rather 		 as motivated ______ than arbitrary
# than 		 motivated rather ______ arbitrary .

# %% [markdown]
# <a id="section-3-1-4-cbow-model"></a>
#
# ## The CBOW Model
#
# <img src="https://lilianweng.github.io/lil-log/assets/images/word2vec-cbow.png" width="500" align="left">

# %% [markdown]
# (Image from https://lilianweng.github.io/lil-log/2017/10/15/learning-word-embedding.html)

# %%
import torch
from torch import nn, optim, tensor, autograd
from torch.nn import functional as F

class CBOW(nn.Module):
    def __init__(self, vocab_size, embd_size, context_size, hidden_size):
        super(CBOW, self).__init__()
        self.embeddings = nn.Embedding(vocab_size, embd_size)
        self.linear1 = nn.Linear(2*context_size*embd_size, hidden_size)
        self.linear2 = nn.Linear(hidden_size, vocab_size)
        
    def forward(self, inputs):
        embedded = self.embeddings(inputs).view((1, -1))
        hid = F.relu(self.linear1(embedded))
        out = self.linear2(hid)
        log_probs = F.log_softmax(out, dim=1)
        return log_probs

# %% [markdown]
# ## Lets take a closer look from the inputs to the first `nn.Linear`
#
# Cos after it reach the first `nn.Linear` it's just the same as our multi-layered perceptron example =)

# %%
w2v_dataset[0]
# Out:
# [{'x': [10, 8, 0, 7], 'y': 11},
#  {'x': [8, 11, 7, 0], 'y': 0},
#  {'x': [11, 0, 0, 7], 'y': 7},
#  {'x': [0, 7, 7, 0], 'y': 0},
#  {'x': [7, 0, 0, 13], 'y': 7},
#  {'x': [0, 7, 13, 3], 'y': 0},
#  {'x': [7, 0, 3, 9], 'y': 13},
#  {'x': [0, 13, 9, 2], 'y': 3},
#  {'x': [13, 3, 2, 10], 'y': 9},
#  {'x': [3, 9, 10, 15], 'y': 2},
#  {'x': [9, 2, 15, 11], 'y': 10},
#  {'x': [2, 10, 11, 5], 'y': 15},
#  {'x': [10, 15, 5, 16], 'y': 11},
#  {'x': [15, 11, 16, 14], 'y': 5},
#  {'x': [11, 5, 14, 0], 'y': 16},
#  {'x': [5, 16, 0, 4], 'y': 14},
#  {'x': [16, 14, 4, 10], 'y': 0},
#  {'x': [14, 0, 10, 8], 'y': 4},
#  {'x': [0, 4, 8, 6], 'y': 10},
#  {'x': [4, 10, 6, 12], 'y': 8},
#  {'x': [10, 8, 12, 1], 'y': 6}]

# %%
# Lets take a look at the first output.


x, y = w2v_dataset[0][0]['x'],  w2v_dataset[0][0]['y']

x = tensor(x)
y = autograd.Variable(tensor(y, dtype=torch.long))
print(x)
print(y)
# Out:
# tensor([10,  8,  0,  7])
# tensor(11)

# %%
embd_size = 5
emb = nn.Embedding(len(w2v_dataset.vocab), embd_size)
emb.state_dict()
# Out:
# OrderedDict([('weight', tensor([[-0.5309, -0.2498,  0.4560,  1.2961, -0.4387],
#                       [ 0.3382, -0.0703,  0.3431,  0.1622,  0.9764],
#                       [ 1.0735, -0.5736, -1.2363, -1.4552,  0.9341],
#                       ...,
#                       [ 1.8404, -2.1452,  1.7231,  1.5320,  0.3120],
#                       [-0.1742,  0.4641,  0.4268, -0.5084, -0.8903],
#                       [-0.2273, -0.4780,  0.2075, -1.3358,  0.0986]]))])

# %%
print(emb.state_dict()['weight'].shape)
emb.state_dict()['weight']
# Out:
# torch.Size([1388, 5])
# tensor([[-0.5309, -0.2498,  0.4560,  1.2961, -0.4387],
#         [ 0.3382, -0.0703,  0.3431,  0.1622,  0.9764],
#         [ 1.0735, -0.5736, -1.2363, -1.4552,  0.9341],
#         ...,
#         [ 1.8404, -2.1452,  1.7231,  1.5320,  0.3120],
#         [-0.1742,  0.4641,  0.4268, -0.5084, -0.8903],
#         [-0.2273, -0.4780,  0.2075, -1.3358,  0.0986]])

# %%
print(emb(x).shape)
print(emb(x))
# Out:
# torch.Size([5, 5])
# tensor([[-0.8014, -2.1698,  0.7498, -0.7403,  1.1497],
#         [ 0.2756,  0.0506, -0.7995, -0.1418,  1.0545],
#         [ 0.2757, -0.2900, -0.3487,  1.7644,  1.2935],
#         [-0.8583,  0.8299,  0.3863, -1.6557,  1.5273],
#         [ 0.8718, -0.5214,  0.2409,  2.1781,  0.0841]],
#        grad_fn=<EmbeddingBackward>)

# %%
print(emb(x).view(1, -1).shape)
emb(x).view(1, -1)
# Out:
# torch.Size([1, 25])
# tensor([[-0.8014, -2.1698,  0.7498, -0.7403,  1.1497,  0.2756,  0.0506, -0.7995,
#          -0.1418,  1.0545,  0.2757, -0.2900, -0.3487,  1.7644,  1.2935, -0.8583,
#           0.8299,  0.3863, -1.6557,  1.5273,  0.8718, -0.5214,  0.2409,  2.1781,
#           0.0841]], grad_fn=<ViewBackward>)

# %%
hidden_size = 100
lin1 = nn.Linear(len(x)*embd_size, hidden_size)
print(lin1.state_dict())
# Out:
# OrderedDict([('weight', tensor([[-0.1447, -0.1136, -0.0130,  ...,  0.0218, -0.1538, -0.1554],
#         [ 0.0928, -0.0122, -0.0744,  ...,  0.1641, -0.1238,  0.1497],
#         [ 0.0631,  0.1008, -0.1635,  ..., -0.0189, -0.0931,  0.1022],
#         ...,
#         [ 0.0705, -0.1190,  0.0672,  ..., -0.0613, -0.0673, -0.0518],
#         [ 0.1590,  0.0873, -0.1814,  ...,  0.0404,  0.1916,  0.1826],
#         [-0.1386,  0.0480,  0.1366,  ...,  0.1606, -0.1528, -0.1577]])), ('bias', tensor([-6.5666e-02, -1.6835e-02, -1.5871e-01, -1.7670e-01, -1.7749e-01,
#         -1.5189e-01, -7.8464e-04,  5.8088e-02,  1.4027e-01, -2.4234e-03,
#          1.2355e-01, -3.1391e-02,  5.7199e-02, -4.8530e-02,  4.8086e-02,
#          8.2727e-02, -5.1193e-02,  8.2017e-02, -1.0416e-01, -1.4997e-01,
#         -1.6799e-01,  1.6884e-01,  1.4976e-01,  1.7572e-01,  7.7179e-02,
#         -5.0694e-05,  1.7845e-01, -1.9768e-01,  1.7715e-01, -1.6373e-01,
#         -1.5114e-01, -1.9456e-01,  3.0764e-02,  7.8759e-02,  1.5015e-01,
#         -9.7355e-02,  5.1287e-02,  1.0298e-01, -1.8547e-01, -1.5008e-01,
#         -1.5821e-01,  4.1172e-02, -1.9167e-01,  1.9523e-02,  5.4097e-02,
#         -7.6474e-02, -8.7699e-02, -1.1582e-01,  1.5503e-02, -7.5769e-02,
#          1.0173e-01,  6.5463e-02, -5.3079e-02,  7.2644e-02, -1.6502e-01,
#          1.5203e-01,  5.4598e-02,  1.2620e-01,  1.6030e-01, -7.4103e-02,
#         -4.3389e-03,  1.4147e-01,  1.7274e-01, -1.3309e-01, -1.6858e-01,
#         -8.1495e-02,  2.4472e-02,  1.2614e-01,  4.2725e-02,  5.0724e-02,
#         -1.8518e-01,  1.5179e-02,  1.2759e-01, -6.9058e-03, -1.4075e-01,
#          3.0420e-02, -1.5410e-01,  6.0003e-02, -5.2466e-02,  3.4459e-02,
#         -6.9183e-02, -9.1366e-04,  1.9327e-01, -1.6089e-01, -1.5696e-01,
#          1.1740e-01,  9.3013e-03, -9.5988e-03,  1.0428e-01,  1.4199e-01,
#          8.6084e-02, -1.9120e-01, -1.3462e-01, -1.4062e-01,  1.0428e-01,
#         -4.6943e-03, -1.9138e-01, -7.7535e-02, -1.1891e-01, -8.0326e-02]))])

# %%
print(lin1.state_dict()['weight'].shape)
print(lin1.state_dict()['weight'])
# Out:
# torch.Size([100, 25])
# tensor([[-0.1447, -0.1136, -0.0130,  ...,  0.0218, -0.1538, -0.1554],
#         [ 0.0928, -0.0122, -0.0744,  ...,  0.1641, -0.1238,  0.1497],
#         [ 0.0631,  0.1008, -0.1635,  ..., -0.0189, -0.0931,  0.1022],
#         ...,
#         [ 0.0705, -0.1190,  0.0672,  ..., -0.0613, -0.0673, -0.0518],
#         [ 0.1590,  0.0873, -0.1814,  ...,  0.0404,  0.1916,  0.1826],
#         [-0.1386,  0.0480,  0.1366,  ...,  0.1606, -0.1528, -0.1577]])

# %%
print(lin1(emb(x).view(1, -1)).shape)
lin1(emb(x).view(1, -1))
# Out:
# torch.Size([1, 100])
# tensor([[-1.2671e+00, -1.0560e+00, -2.7547e-01, -3.9239e-01,  1.0550e+00,
#           5.8454e-02,  2.7364e-01, -2.1694e-01, -4.2596e-01, -3.0849e-02,
#          -3.5111e-01, -6.6442e-01,  4.4285e-01, -1.4273e+00, -1.0141e-01,
#           8.4337e-01, -8.1876e-01, -5.3560e-01, -9.8946e-01, -2.4821e-01,
#           4.9500e-01,  2.4280e-01, -1.3943e+00, -8.1615e-02, -9.4806e-03,
#          -6.5384e-01, -2.9202e-01, -2.0307e-01,  3.1281e-02, -1.1027e+00,
#           6.8971e-01,  9.4438e-01,  2.0563e-01,  4.3321e-01,  1.1221e-01,
#          -1.1211e-01,  5.7779e-01, -1.8758e-01, -6.2340e-01, -8.7328e-02,
#          -1.1230e+00,  7.8058e-01,  7.0934e-01, -6.2332e-01,  2.4691e-01,
#           2.1622e-03,  5.3593e-01,  2.7730e-01, -2.6210e-01, -2.6775e-01,
#           1.9049e-01,  1.1417e+00,  5.3801e-01,  1.1117e+00, -1.4210e-01,
#           4.8679e-02,  4.3074e-01, -3.6613e-01,  2.2502e-01, -6.7378e-01,
#          -1.4379e+00, -2.8330e-01, -7.2398e-01,  4.0467e-01,  6.0282e-02,
#           5.6468e-01,  5.9446e-01, -4.7270e-01, -4.6316e-04,  3.6583e-01,
#          -3.5283e-01, -2.2937e-01, -8.3883e-01,  8.8644e-01,  7.8209e-01,
#           1.8374e-01, -8.0843e-01,  5.6022e-01,  3.5172e-01,  8.9698e-02,
#           5.1242e-01,  8.1732e-01,  9.9344e-01, -7.4383e-01, -1.3861e+00,
#           7.1379e-01,  1.6392e-01,  5.7822e-02, -2.7016e-01, -9.9921e-02,
#           6.5376e-01,  4.5806e-02, -1.0812e+00, -2.3341e-01, -7.0661e-01,
#          -2.5833e-01, -1.3970e-01,  3.9231e-01,  6.4453e-01, -7.6688e-01]],
#        grad_fn=<AddmmBackward>)

# %%
relu = nn.ReLU()
print(relu(lin1(emb(x).view(1, -1))).shape)
relu(lin1(emb(x).view(1, -1)))
# Out:
# torch.Size([1, 100])
# tensor([[0.0000, 0.0000, 0.0000, 0.0000, 1.0550, 0.0585, 0.2736, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.4429, 0.0000, 0.0000, 0.8434, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.4950, 0.2428, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0313, 0.0000, 0.6897, 0.9444, 0.2056, 0.4332, 0.1122, 0.0000,
#          0.5778, 0.0000, 0.0000, 0.0000, 0.0000, 0.7806, 0.7093, 0.0000, 0.2469,
#          0.0022, 0.5359, 0.2773, 0.0000, 0.0000, 0.1905, 1.1417, 0.5380, 1.1117,
#          0.0000, 0.0487, 0.4307, 0.0000, 0.2250, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.4047, 0.0603, 0.5647, 0.5945, 0.0000, 0.0000, 0.3658, 0.0000, 0.0000,
#          0.0000, 0.8864, 0.7821, 0.1837, 0.0000, 0.5602, 0.3517, 0.0897, 0.5124,
#          0.8173, 0.9934, 0.0000, 0.0000, 0.7138, 0.1639, 0.0578, 0.0000, 0.0000,
#          0.6538, 0.0458, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.3923, 0.6445,
#          0.0000]], grad_fn=<ThresholdBackward0>)

# %%
lin2 = nn.Linear(hidden_size, len(w2v_dataset.vocab))
print(lin2.state_dict()['weight'].shape)
lin2.state_dict()['weight']
# Out:
# torch.Size([1388, 100])
# tensor([[ 0.0725, -0.0418, -0.0470,  ...,  0.0875,  0.0200, -0.0492],
#         [-0.0359, -0.0547,  0.0733,  ..., -0.0528,  0.0927, -0.0141],
#         [-0.0723,  0.0796,  0.0544,  ...,  0.0629,  0.0833, -0.0260],
#         ...,
#         [ 0.0161, -0.0200, -0.0464,  ...,  0.0278,  0.0099, -0.0537],
#         [ 0.0719, -0.0236, -0.0734,  ..., -0.0269,  0.0578, -0.0877],
#         [-0.0688,  0.0176, -0.0377,  ...,  0.0769,  0.0392, -0.0416]])

# %%
h_x = relu(lin1(emb(x).view(1, -1)))
print(lin2(h_x).shape)
lin2(h_x)
# Out:
# torch.Size([1, 1388])
# tensor([[-0.4737,  0.2024, -0.0957,  ...,  0.3202, -0.3416,  0.1011]],
#        grad_fn=<AddmmBackward>)

# %%
softmax = nn.LogSoftmax(dim=1)
softmax(lin2(h_x)).detach().numpy().tolist()
# Out:
# [[-7.729094505310059,
#   -7.0529561042785645,
#   -7.351128578186035,
#   -6.980468273162842,
#   -7.116093635559082,
#   -7.565708160400391,
#   -7.476498126983643,
#   -7.222686290740967,
#   -7.558962821960449,
#   -7.518165111541748,
#   -7.190613269805908,
#   -7.156388759613037,
#   -6.849654197692871,
#   -7.481348037719727,
#   -7.07505989074707,
#   -6.886816501617432,
#   -7.235705375671387,
#   -7.411858081817627,
#   -7.311549663543701,
#   -7.299731254577637,
#   -7.217769622802734,
#   -7.277176856994629,
#   -7.421562194824219,
#   -6.878456115722656,
#   -7.575339317321777,
#   -7.339748859405518,
#   -7.422872543334961,
#   -7.513821125030518,
#   -7.49839448928833,
#   -7.398869037628174,
#   -7.750196933746338,
#   -7.4314680099487305,
#   -7.4705376625061035,
#   -7.6934428215026855,
#   -7.543959140777588,
#   -7.3512349128723145,
#   -7.210240840911865,
#   -7.472490310668945,
#   -6.894967555999756,
#   -6.933655261993408,
#   -7.336376190185547,
#   -7.370111465454102,
#   -7.811978816986084,
#   -7.320084571838379,
#   -7.04032564163208,
#   -7.789002418518066,
#   -7.500626087188721,
#   -7.083990097045898,
#   -7.296184062957764,
#   -7.3265204429626465,
#   -7.356484413146973,
#   -7.371758460998535,
#   -7.369817733764648,
#   -7.010770797729492,
#   -7.11646032333374,
#   -7.373289108276367,
#   -7.3422532081604,
#   -7.546531677246094,
#   -6.805144309997559,
#   -7.377241134643555,
#   -6.935293674468994,
#   -7.486011028289795,
#   -7.41392183303833,
#   -6.975214958190918,
#   -7.327785015106201,
#   -6.8284454345703125,
#   -7.475903034210205,
#   -7.221606731414795,
#   -7.350489139556885,
#   -7.238546371459961,
#   -7.310493469238281,
#   -7.662026405334473,
#   -7.140270709991455,
#   -7.260220527648926,
#   -7.143528938293457,
#   -7.412703990936279,
#   -7.172358989715576,
#   -7.257887840270996,
#   -6.978217124938965,
#   -7.7122979164123535,
#   -7.573696613311768,
#   -7.172189235687256,
#   -7.100217342376709,
#   -7.075109958648682,
#   -7.040386199951172,
#   -7.240696907043457,
#   -6.989405155181885,
#   -7.670687198638916,
#   -7.5658674240112305,
#   -7.149800777435303,
#   -7.274951934814453,
#   -7.070123672485352,
#   -7.376152038574219,
#   -7.389297962188721,
#   -7.281641960144043,
#   -7.405422210693359,
#   -7.53994083404541,
#   -7.2004523277282715,
#   -7.496983051300049,
#   -7.108113765716553,
#   -7.446785926818848,
#   ...]]

# %%
# Select the index with highest softmax probabilities
# See https://pytorch.org/docs/stable/torch.html#torch.max
torch.max(softmax(lin2(h_x)), 1)
# Out:
# (tensor([-6.5388], grad_fn=<MaxBackward0>), tensor([1136]))

# %% [markdown]
# <a id="section-3-1-4-train-cbow"></a>
#
# # Now, we train the CBOW model for real.

# %%
# First we split the data into training and testing.
from sklearn.model_selection import train_test_split

tokenized_text_train, tokenized_text_test = train_test_split(tokenized_text, test_size=0.1, random_state=42)
len(tokenized_text_train), len(tokenized_text_test)
# Out:
# (211, 24)

# %%
### Hint: Click here to go back up to see the CBOW model

# %%
import torch
from torch import nn, optim, tensor, autograd
from torch.nn import functional as F

class CBOW(nn.Module):
    def __init__(self, vocab_size, embd_size, context_size, hidden_size):
        super(CBOW, self).__init__()
        self.embeddings = nn.Embedding(vocab_size, embd_size)
        self.linear1 = nn.Linear(2*context_size*embd_size, hidden_size)
        self.linear2 = nn.Linear(hidden_size, vocab_size)
        
    def forward(self, inputs):
        # Put the input context indices into the embeddings
        # then squeeze it into a single dimension vector with tensor.view((1,-1))
        embedded = self.???(inputs).view((1, -1))
        # Put the embedding input through linear layer,
        # then an activation function to create the hidden layer.
        hid = F.relu(self.???(embedded))
        # Put the hidden layer through a second linear layer,
        out = self.???(hid)
        # then a last layer activation function to generate
        # pobabilities, hint https://pytorch.org/docs/stable/nn.html#torch.nn.functional.log_softmax
        log_probs = F.???(out, dim=1)
        return log_probs

# %%
embd_size = 100
learning_rate = 0.003
hidden_size = 100
window_size = 2

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Initialize the dataset.
w2v_dataset = Word2VecText(tokenized_text_train, window_size=window_size, variant='cbow')
vocab_size = len(w2v_dataset.vocab)

criterion = nn.NLLLoss()
# Hint: the CBOW model object you've created.
model = ???(vocab_size, embd_size, window_size, hidden_size).to(device)
optimizer = optim.???(model.parameters(), lr=learning_rate)

losses = []

model = nn.DataParallel(model)

num_epochs = 100
for _e in tqdm(range(num_epochs)):
    epoch_loss = []
    for sent_idx in range(w2v_dataset._len):
        for w2v_io in w2v_dataset[sent_idx]:
            # Zero gradient.
            optimizer.zero_grad()
            # Retrieve the inputs and outputs.
            x, y = w2v_io['x'], w2v_io['y']
            x = tensor(x).to(device)
            y = autograd.Variable(tensor(y, dtype=torch.long)).to(device)
            # Calculate the log probability of the context embeddings.
            logprobs = ???(x)
            # This unsqueeze thing is really a feature/bug... -_-
            loss = ???(logprobs, y.unsqueeze(0)) 
            loss.???()
            optimizer.???()
            epoch_loss.append(float(loss))
    # Save model after every epoch.
    torch.save(model.state_dict(), 'cbow_checkpoint_{}.pt'.format(_e))
    losses.append(sum(epoch_loss)/len(epoch_loss))
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Exception in thread Thread-17:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tqdm/_tqdm.py", line 148, in run
#     for instance in self.tqdm_cls._instances:
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/_weakrefset.py", line 60, in __iter__
#     for itemref in self.data:
# RuntimeError: Set changed size during iteration
#
#   2%|▏         | 2/100 [00:13<11:19,  6.94s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-158-88187b730388> in <module>
#      33             # This unsqueeze thing is really a feature/bug... -_-
#      34             loss = criterion(logprobs, y.unsqueeze(0))
# ---> 35             loss.backward()
#      36             optimizer.step()
#      37             epoch_loss.append(float(loss))
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     100                 products. Defaults to ``False``.
#     101         """
# --> 102         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     103
#     104     def register_hook(self, hook):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      88     Variable._execution_engine.run_backward(
#      89         tensors, grad_tensors, retain_graph, create_graph,
# ---> 90         allow_unreachable=True)  # allow_unreachable flag
#      91
#      92
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

sns.set_style("darkgrid")
sns.set(rc={'figure.figsize':(12, 8)})

plt.plot(losses)
plt.show()

# %% [markdown]
# <a id="section-3-1-4-evaluate-cbow"></a>
#
# # Apply and Evaluate the CBOW Model

# %%
from lazyme import color_str

true_positive = 0
all_data = 0
# Iterate through the test sentences. 
for sent in tokenized_text_test:
    # Extract all the CBOW contexts (X) and targets (Y)
    for w2v_io in w2v_dataset._iterator(w2v_dataset.vectorize(sent)):
        # Retrieve the inputs and outputs.
        x = tensor(w2v_io['x']).to(device)
        y = tensor(w2v_io['y']).to(device)
        if -1 in x: # Skip unknown words.
            continue
            
        with torch.no_grad():
            # Remember how to get the best prediction output? 
            # Hint: https://pytorch.org/docs/stable/torch.html#torch.max
            _, prediction =  torch.???(model(x), 1)
        true_positive += int(prediction) == int(y)
        visualize_predictions(x, y, prediction, w2v_dataset.vocab, window_size=window_size)
        all_data += 1
# Out:
# is 		 the problem is essentially this
# essentially 	 problem is the this :
# this 		 is essentially the : if
# : 		 essentially this ______ if a
# if 		 this : for a word
# a 		 : if and word (
# word 		 if a ( ( or
# ( 		 a word ______ or bigram
# or 		 word ( and bigram ,
# bigram 		 ( or ) , or
# <unk> 		 , or is , or
# <unk> 		 , or and etc .
# is 		 the web of a vast
# a 		 web is not vast re-
# vast 		 is a the re- source
# re- 		 a vast of source for
# source 		 vast re- ______ for many
# the 		 is that the association is
# association 	 that the ______ is random
# is 		 the association is random ,
# random 		 association is the , arbitrary
# , 		 is random ______ arbitrary ,
# arbitrary 	 random , and , motivated
# , 		 , arbitrary ______ motivated or
# motivated 	 arbitrary , and or pre-
# <unk> 		 or pre- ) ( r
# , 		 ( r ) a ,
# <unk> 		 a , ever , p
# their 		 however , and methods are
# example 	 , for the , from
# , 		 for example ______ from just
# from 		 example , and just those
# <unk> 		 just those the errors that
# they 		 , and the do not
# do 		 and they is not wish
# not 		 they do not wish to
# <unk> 		 wish to and any scf
# for 		 any scf the which there
# which 		 scf for the there is
# there 		 for which the is any
# is 		 which there is any evidence
# any 		 there is the evidence as
# evidence 	 is any ______ as a
# as 		 any evidence is a true
# a 		 evidence as the true scf
# true 		 as a the scf for
# scf 		 a true is for the
# for 		 true scf that the verb
# the 		 scf for the verb .
# <unk> 		 some way ______ out to
# was 		 tion that ______ indistinguishable from
# indistinguishable 	 that was is from one
# from 		 was indistinguishable ______ one where
# one 		 indistinguishable from and where the
# where 		 from one in the individual
# the 		 one where ______ individual words
# individual 	 where the and words (
# words 		 the individual is ( as
# ( 		 individual words ( as opposed
# as 		 words ( and opposed to
# opposed 	 ( as ) to the
# to 		 as opposed of the texts
# the 		 opposed to ( texts )
# texts 		 to the null ) had
# ) 		 the texts of had been
# had 		 texts ) the been randomly
# been 		 ) had ______ randomly selected
# randomly 	 had been ______ selected ,
# selected 	 been randomly is , this
# <unk> 		 , this ______ out not
# to 		 out not to be the
# be 		 not to and the case
# the 		 to be is case .
# <unk> 		 ted and and carroll 1997
# <unk> 		 1997 automatic the of subcategorization
# from 		 of subcategorization ______ corpora .
# were 		 the ho is tested using
# tested 		 ho were to using the
# <unk> 		 using the null : is
# <unk> 		 ⫺ e ______ ⫺ 0.5
# <unk> 		 ) 2 a greater than
# the 		 greater than ______ critical value
# critical 	 than the the value ?
# <unk> 		 schütze 1999 the of statistical
# natural 	 of statistical ______ language processing
# language 	 statistical natural ______ processing .
# likelihood 	 if the ______ is low
# is 		 the likelihood ______ low ,
# low 		 likelihood is not , we
# , 		 is low ______ we reject
# we 		 low , and reject h0
# reject 		 , we ______ h0 .
# the 		 however where the sample size
# <unk> 		 sample size ______ by an
# <unk> 		 order of the , or
# where 		 , or the it is
# it 		 or where ) is enormous
# is 		 where it is enormous ,
# enormous 	 it is not , it
# , 		 is enormous ______ it is
# it 		 enormous , and is wrong
# is 		 , it is wrong to
# wrong 		 it is not to identify
# to 		 is wrong to identify the
# <unk> 		 identify the ______ distinction with
# <unk> 		 with the ______ one .
# the 		 proceedings of the conference of
# conference 	 of the not of the
# is 		 false assumptions the often an
# <unk> 		 often an the way to
# <unk> 		 way to and ; the
# <unk> 		 the problem is where the
# <unk> 		 of the ______ is overlooked
# linguistics 	 compu- tational and 16 (
# 16 		 tational linguistics ______ ( 1
# ( 		 linguistics 16 ( 1 )
# 1 		 16 ( x ) ,
# is 		 conclusion language ______ non-random and
# non-random 	 language is not and hence
# and 		 is non-random the hence ,
# hence 		 non-random and is , when
# , 		 and hence ______ when we
# when 		 hence , and we look
# we 		 , when ______ look at
# look 		 when we the at linguistic
# , 		 in corpora in the null
# the 		 corpora , the null hypothesis
# null 		 , the null hypothesis will
# hypothesis 	 the null hypothesis will never
# will 		 null hypothesis is never be
# never 		 hypothesis will the be true
# be 		 will never ______ true .
# not 		 we do not always have
# always 		 do not ______ have enough
# have 		 not always the enough data
# enough 		 always have a data to
# data 		 have enough ______ to reject
# to 		 enough data ______ reject the
# reject 		 data to and the null
# the 		 to reject the null hypothesis
# null 		 reject the null hypothesis ,
# hypothesis 	 the null hypothesis , but
# , 		 null hypothesis is but that
# but 		 hypothesis , the that is
# that 		 , but ______ is a
# <unk> 		 is a the issue :
# wherever 	 issue : ______ there is
# there 		 : wherever ______ is enough
# is 		 wherever there is enough data
# enough 		 there is not data ,
# data 		 is enough ______ , it
# , 		 enough data ______ it is
# it 		 data , and is rejected
# is 		 , it is rejected .
# in 		 since words ______ a text
# a 		 words in the text are
# text 		 in a and are not
# are 		 a text is not random
# not 		 text are ______ random ,
# random 		 are not ______ , we
# , 		 not random ______ we know
# we 		 random , the know that
# know 		 , we ______ that our
# that 		 we know the our corpora
# our 		 know that the corpora are
# corpora 	 that our ______ are not
# are 		 our corpora is not randomly
# not 		 corpora are ______ randomly generated
# randomly 	 are not ______ generated ,
# generated 	 not randomly ______ , and
# , 		 randomly generated ______ and the
# and 		 generated , and the hypothesis
# the 		 , and null hypothesis test
# hypothesis 	 and the ______ test con-
# <unk> 		 test con- in the fact
# <unk> 		 cases are the in section
# <unk> 		 of linguistic ______ concern the
# <unk> 		 the dis- not between a
# <unk> 		 a and and a linguistic
# <unk> 		 a linguistic and of a
# <unk> 		 reason to that the relation
# between 	 the relation of , for
# , 		 relation between is for example
# for 		 between , and example ,
# example 	 , for ) , a
# , 		 for example ______ a verb
# a 		 example , and verb ’
# verb 		 , a ______ ’ s
# ’ 		 a verb of s syntax
# s 		 verb ’ ______ syntax and
# syntax 		 ’ s ______ and its
# <unk> 		 and its the , as
# motivated 	 , as is rather than
# rather 		 as motivated and than arbitrary
# than 		 motivated rather ______ arbitrary .
# value 		 the average to of the
# of 		 average value of the error
# the 		 value of the error term
# error 		 of the and term ,
# term 		 the error of , language
# , 		 error term is language is
# language 	 term , and is never
# is 		 , language is never ,
# never 		 language is not , ever
# , 		 is never ______ ever ,
# ever 		 never , ever , ever
# , 		 , ever ______ ever ,
# ever 		 ever , ever , random
# <unk> 		 ) 2 and is then
# <unk> 		 is then of the hypothesis
# <unk> 		 can , ever , be
# <unk> 		 , be is as :
# are 		 as : for the error
# the 		 : are the error terms
# error 		 are the two terms systematically
# terms 		 the error hypothesis systematically greater
# systematically 	 error terms is greater than
# greater 	 terms systematically ______ than 0.5
# than 		 systematically greater ______ 0.5 ?
# 1 		 with just the % of
# % 		 just 1 ______ of them
# of 		 1 % ______ them ,
# them 		 % of the , devastate
# <unk> 		 , devastate ______ one of
# the 		 one of the verbs for
# verbs 		 of the null for which
# for 		 the verbs of which we
# which 		 verbs for ______ we have
# <unk> 		 we have the of data
# <unk> 		 , and are thresholding methods
# will 		 thresholding methods the distinguish associated
# distinguish 	 methods will is associated scfs
# associated 	 will distinguish ______ scfs from
# scfs 		 distinguish associated is from noise
# from 		 associated scfs and noise .

# %%
torch.max(model(x), 1)
#model(x)
# Out:
# (tensor([-2.3261], grad_fn=<MaxBackward0>), tensor([4]))

# %%
print('Accuracy:', true_positive/all_data)
# Out:
# Accuracy: 0.1829787234042553

# %% [markdown]
# <a id="section-3-1-4-load-model"></a>
#
# # Go back to the 5th Epoch

# %%
model_5 = CBOW(vocab_size, embd_size, window_size, hidden_size)
model_5 = torch.nn.DataParallel(model_5)
model_5.load_state_dict(torch.load('cbow_checkpoint_5.pt'))
model_5.eval()
# Out:
# DataParallel(
#   (module): CBOW(
#     (embeddings): Embedding(1303, 100)
#     (linear1): Linear(in_features=400, out_features=100, bias=True)
#     (linear2): Linear(in_features=100, out_features=1303, bias=True)
#   )
# )

# %%
true_positive = 0
all_data = 0
# Iterate through the test sentences. 
for sent in tokenized_text_test:
    # Extract all the CBOW contexts (X) and targets (Y)
    for w2v_io in w2v_dataset._iterator(w2v_dataset.vectorize(sent)):
        # Retrieve the inputs and outputs.
        x = tensor(w2v_io['x']).to(device)
        y = tensor(w2v_io['y']).to(device)
        
        if -1 in x: # Skip unknown words.
            continue
            
        with torch.no_grad():
            _, prediction =  torch.max(model_5(x), 1)
        true_positive += int(prediction) == int(y)
        visualize_predictions(x, y, prediction, w2v_dataset.vocab, window_size=window_size)
        all_data += 1
# Out:
# is 		 the problem ______ essentially this
# essentially 	 problem is the this :
# this 		 is essentially to : if
# : 		 essentially this ______ if a
# if 		 this : of a word
# a 		 : if as word (
# word 		 if a to ( or
# ( 		 a word ______ or bigram
# or 		 word ( as bigram ,
# bigram 		 ( or ) , or
# <unk> 		 , or random , or
# <unk> 		 , or by etc .
# is 		 the web is a vast
# a 		 web is in vast re-
# vast 		 is a to re- source
# re- 		 a vast of source for
# source 		 vast re- ______ for many
# the 		 is that the association is
# association 	 that the sample is random
# is 		 the association ______ random ,
# random 		 association is data , arbitrary
# , 		 is random ______ arbitrary ,
# arbitrary 	 random , random , motivated
# , 		 , arbitrary ______ motivated or
# motivated 	 arbitrary , and or pre-
# <unk> 		 or pre- p ( r
# , 		 ( r is a ,
# <unk> 		 a , random , p
# their 		 however , and methods are
# example 	 , for random , from
# , 		 for example of from just
# from 		 example , and just those
# <unk> 		 just those the errors that
# they 		 , and a do not
# do 		 and they are not wish
# not 		 they do be wish to
# <unk> 		 wish to and any scf
# for 		 any scf ______ which there
# which 		 scf for the there is
# there 		 for which there is any
# is 		 which there is any evidence
# any 		 there is no evidence as
# evidence 	 is any ______ as a
# as 		 any evidence is a true
# a 		 evidence as data true scf
# true 		 as a of scf for
# scf 		 a true ______ for the
# for 		 true scf of the verb
# the 		 scf for the verb .
# <unk> 		 some way to out to
# was 		 tion that of indistinguishable from
# indistinguishable 	 that was of from one
# from 		 was indistinguishable ( one where
# one 		 indistinguishable from to where the
# where 		 from one of the individual
# the 		 one where to individual words
# individual 	 where the same words (
# words 		 the individual ______ ( as
# ( 		 individual words ______ as opposed
# as 		 words ( as opposed to
# opposed 	 ( as ) to the
# to 		 as opposed of the texts
# the 		 opposed to ( texts )
# texts 		 to the probability ) had
# ) 		 the texts is had been
# had 		 texts ) ______ been randomly
# been 		 ) had the randomly selected
# randomly 	 had been language selected ,
# selected 	 been randomly corpora , this
# <unk> 		 , this and out not
# to 		 out not can be the
# be 		 not to for the case
# the 		 to be the case .
# <unk> 		 ted and a carroll 1997
# <unk> 		 1997 automatic population of subcategorization
# from 		 of subcategorization and corpora .
# were 		 the ho of tested using
# tested 		 ho were for using the
# <unk> 		 using the two : is
# <unk> 		 ⫺ e and ⫺ 0.5
# <unk> 		 ) 2 ______ greater than
# the 		 greater than the critical value
# critical 	 than the two value ?
# <unk> 		 schütze 1999 number of statistical
# natural 	 of statistical ______ language processing
# language 	 statistical natural the processing .
# likelihood 	 if the which is low
# is 		 the likelihood ______ low ,
# low 		 likelihood is data , we
# , 		 is low the we reject
# we 		 low , random reject h0
# reject 		 , we shall h0 .
# the 		 however where the sample size
# <unk> 		 sample size is by an
# <unk> 		 order of data , or
# where 		 , or that it is
# it 		 or where there is enormous
# is 		 where it is enormous ,
# enormous 	 it is data , it
# , 		 is enormous the it is
# it 		 enormous , there is wrong
# is 		 , it is wrong to
# wrong 		 it is not to identify
# to 		 is wrong to identify the
# <unk> 		 identify the same distinction with
# <unk> 		 with the same one .
# the 		 proceedings of the conference of
# conference 	 of the probability of the
# is 		 false assumptions to often an
# <unk> 		 often an to way to
# <unk> 		 way to ) ; the
# <unk> 		 the problem is where the
# <unk> 		 of the probability is overlooked
# linguistics 	 compu- tational linguistics 16 (
# 16 		 tational linguistics 2 ( 1
# ( 		 linguistics 16 ( 1 )
# 1 		 16 ( 1 ) ,
# is 		 conclusion language is non-random and
# non-random 	 language is ______ and hence
# and 		 is non-random ______ hence ,
# hence 		 non-random and data , when
# , 		 and hence ______ when we
# when 		 hence , and we look
# we 		 , when and look at
# look 		 when we the at linguistic
# , 		 in corpora reject the null
# the 		 corpora , the null hypothesis
# null 		 , the null hypothesis will
# hypothesis 	 the null hypothesis will never
# will 		 null hypothesis random never be
# never 		 hypothesis will never be true
# be 		 will never be true .
# not 		 we do ( always have
# always 		 do not we have enough
# have 		 not always in enough data
# enough 		 always have to data to
# data 		 have enough data to reject
# to 		 enough data to reject the
# reject 		 data to reject the null
# the 		 to reject the null hypothesis
# null 		 reject the null hypothesis ,
# hypothesis 	 the null hypothesis , but
# , 		 null hypothesis ______ but that
# but 		 hypothesis , which that is
# that 		 , but ______ is a
# <unk> 		 is a to issue :
# wherever 	 issue : ______ there is
# there 		 : wherever there is enough
# is 		 wherever there is enough data
# enough 		 there is enough data ,
# data 		 is enough data , it
# , 		 enough data ______ it is
# it 		 data , there is rejected
# is 		 , it and rejected .
# in 		 since words in a text
# a 		 words in which text are
# text 		 in a and are not
# are 		 a text of not random
# not 		 text are the random ,
# random 		 are not data , we
# , 		 not random ______ we know
# we 		 random , and know that
# know 		 , we shall that our
# that 		 we know and our corpora
# our 		 know that and corpora are
# corpora 	 that our ______ are not
# are 		 our corpora is not randomly
# not 		 corpora are the randomly generated
# randomly 	 are not and generated ,
# generated 	 not randomly ) , and
# , 		 randomly generated ______ and the
# and 		 generated , with the hypothesis
# the 		 , and null hypothesis test
# hypothesis 	 and the to test con-
# <unk> 		 test con- for the fact
# <unk> 		 cases are very in section
# <unk> 		 of linguistic ______ concern the
# <unk> 		 the dis- and between a
# <unk> 		 a and two a linguistic
# <unk> 		 a linguistic of of a
# <unk> 		 reason to reject the relation
# between 	 the relation ) , for
# , 		 relation between ______ for example
# for 		 between , and example ,
# example 	 , for random , a
# , 		 for example in a verb
# a 		 example , and verb ’
# verb 		 , a is ’ s
# ’ 		 a verb ’ s syntax
# s 		 verb ’ ______ syntax and
# syntax 		 ’ s ______ and its
# <unk> 		 and its data , as
# motivated 	 , as or rather than
# rather 		 as motivated of than arbitrary
# than 		 motivated rather ______ arbitrary .
# value 		 the average conference of the
# of 		 average value of the error
# the 		 value of the error term
# error 		 of the same term ,
# term 		 the error hypothesis , language
# , 		 error term is language is
# language 	 term , language is never
# is 		 , language is never ,
# never 		 language is never , ever
# , 		 is never ______ ever ,
# ever 		 never , ever , ever
# , 		 , ever ______ ever ,
# ever 		 ever , ever , random
# <unk> 		 ) 2 there is then
# <unk> 		 is then in the hypothesis
# <unk> 		 can , random , be
# <unk> 		 , be is as :
# are 		 as : of the error
# the 		 : are or error terms
# error 		 are the same terms systematically
# terms 		 the error term systematically greater
# systematically 	 error terms to greater than
# greater 	 terms systematically to than 0.5
# than 		 systematically greater the 0.5 ?
# 1 		 with just the % of
# % 		 just 1 all of them
# of 		 1 % and them ,
# them 		 % of the , devastate
# <unk> 		 , devastate ______ one of
# the 		 one of the verbs for
# verbs 		 of the null for which
# for 		 the verbs ______ which we
# which 		 verbs for the we have
# <unk> 		 we have number of data
# <unk> 		 , and and thresholding methods
# will 		 thresholding methods ______ distinguish associated
# distinguish 	 methods will ______ associated scfs
# associated 	 will distinguish random scfs from
# scfs 		 distinguish associated with from noise
# from 		 associated scfs ______ noise .

# %%
print('Accuracy:', true_positive/all_data)
# Out:
# Accuracy: 0.22127659574468084

# %%
model(x).shape[1] == len(w2v_dataset.vocab)
# Out:
# True

# %% [markdown]
# # [optional] How to Handle Unknown Words?
#
# This is not the best way to handle unknown words, but we can simply assign an index for unknown words.
#
# **Hint:** Ensure that you have `gensim` version >= 3.7.0 first. Otherwise this part of the code won't work.
#
# Try in your Python environment installation:
#
# ```
# python -m pip install -U pip
# python -m pip install -U gensim>=3.7.0
# ```
#
# Or within the jupyter notebook:

# %%
# !python -m pip install -U pip
# !python -m pip install -U gensim>=3.7.0
# Out:
# DEPRECATION: Python 2.7 will reach the end of its life on January 1st, 2020. Please upgrade your Python as Python 2.7 won't be maintained after that date. A future version of pip will drop support for Python 2.7.
# Requirement already up-to-date: pip in /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages (19.0.2)
# DEPRECATION: Python 2.7 will reach the end of its life on January 1st, 2020. Please upgrade your Python as Python 2.7 won't be maintained after that date. A future version of pip will drop support for Python 2.7.

# %% [markdown]
# To check version of `gensim` after installation:

# %%
import gensim
gensim.__version__
# Out:
# '3.7.0'

# %%
vocab = Dictionary(['this is a foo bar sentence'.split()])
dict(vocab.items())
# Out:
# {0: 'a', 1: 'bar', 2: 'foo', 3: 'is', 4: 'sentence', 5: 'this'}

# %%
# See https://radimrehurek.com/gensim/corpora/dictionary.html#gensim.corpora.dictionary.Dictionary.patch_with_special_tokens
vocab = Dictionary(['this is a foo bar sentence'.split()])

try:
    special_tokens = {'<pad>': 0, '<unk>': 1}
    vocab.patch_with_special_tokens(special_tokens)
except: # If gensim is not 3.7.0
    pass
    
dict(vocab.items())
# Out:
# {6: 'a',
#  7: 'bar',
#  2: 'foo',
#  3: 'is',
#  4: 'sentence',
#  5: 'this',
#  0: '<pad>',
#  1: '<unk>'}

# %% [markdown]
# # [optional] Lets Rewrite the `Word2VecText` Object
#
# Now with the (i) unknown word patch in the vocabulary as well as (ii) `skipgram_iterator`

# %%
class Word2VecText(Dataset):
    def __init__(self, tokenized_texts, window_size, variant):
        """
        :param tokenized_texts: Tokenized text.
        :type tokenized_texts: list(list(str))
        """
        self.sents = tokenized_texts
        self._len = len(self.sents)
        
        # Add the unknown word patch here.
        self.vocab = Dictionary(self.sents)
        try:
            special_tokens = {'<pad>': 0, '<unk>': 1}
            self.vocab.patch_with_special_tokens(special_tokens)
        except:
            pass
        
        self.window_size = window_size
        self.variant = variant
        if variant.lower() == 'cbow':
            self._iterator = partial(self.cbow_iterator, window_size=self.window_size)
        elif variant.lower() == 'skipgram':
            self._iterator = partial(self.skipgram_iterator, window_size=self.window_size)

    def __getitem__(self, index):
        """
        The primary entry point for PyTorch datasets.
        This is were you access the specific data row you want.
        
        :param index: Index to the data point.
        :type index: int
        """
        vectorized_sent = self.vectorize(self.sents[index])
        
        return list(self._iterator(vectorized_sent))

    def __len__(self):
        return self._len
    
    def vectorize(self, tokens):
        """
        :param tokens: Tokens that should be vectorized. 
        :type tokens: list(str)
        """
        # See https://radimrehurek.com/gensim/corpora/dictionary.html#gensim.corpora.dictionary.Dictionary.doc2idx 
        return self.vocab.doc2idx(tokens, unknown_word_index=1)
    
    def unvectorize(self, indices):
        """
        :param indices: Converts the indices back to tokens.
        :type tokens: list(int)
        """
        return [self.vocab[i] for i in indices]
    
    def cbow_iterator(self, tokens, window_size):
        n = window_size * 2 + 1
        for window in per_window(tokens, n):
            target = window.pop(window_size)
            yield {'x': window, 'y': target}   # X = window ; Y = target. 
            
    def skipgram_iterator(self, tokens, window_size):
        n = window_size * 2 + 1 
        for i, window in enumerate(per_window(tokens, n)):
            focus = window.pop(window_size)
            # Generate positive samples.
            for context_word in window:
                yield {'x': (focus, context_word), 'y':1}
            # Generate negative samples.
            for _ in range(n-1):
                leftovers = tokens[:i] + tokens[i+n:]
                if leftovers:
                    yield {'x': (focus, random.choice(leftovers)), 'y':0}

# %% [markdown]
# <a id="section-3-1-5"></a>
#
# # Lets try the skipgram task

# %%
class SkipGram(nn.Module):
    def __init__(self, vocab_size, embd_size):
        super(SkipGram, self).__init__()
        self.embeddings = nn.Embedding(vocab_size, embd_size)
    
    def forward(self, focus, context):
        embed_focus = self.embeddings(focus).view((1, -1))
        embed_context = self.embeddings(context).view((1, -1))
        # See https://pytorch.org/docs/stable/torch.html#torch.t
        score = torch.mm(embed_focus, torch.t(embed_context))
        log_probs = F.logsigmoid(score)
        return log_probs

# %% [markdown]
# <a id="section-3-1-5-foward"></a>
#
# # Take a closer look at what's in the `forward()`

# %%
xx1 = torch.rand(1,20)
xx2 = torch.rand(1,20)

xx1_numpy = xx1.detach().numpy()
xx2_numpy = xx2.detach().numpy()

# %%
print(xx1_numpy.shape)
print(xx2_numpy.T.shape)
print(np.dot(xx1_numpy, xx2_numpy.T))
# Out:
# (1, 20)
# (20, 1)
# [[5.7234097]]

# %%
print(xx1.shape)
print(torch.t(xx2).shape) 

print(torch.mm(xx1, torch.t(xx2))) #
# Out:
# torch.Size([1, 20])
# torch.Size([20, 1])
# tensor([[5.7234]])

# %% [markdown]
# <a id="section-3-1-5-train"></a>
#
# # Train a Skipgram model (for real)

# %%
embd_size = 100
learning_rate = 0.03
hidden_size = 300
window_size = 3

# Initialize the dataset.
w2v_dataset = Word2VecText(tokenized_text_train, window_size=3, variant='skipgram')
vocab_size = len(w2v_dataset.vocab)

criterion = nn.MSELoss()
# Use the Skipgram object
model = ???(vocab_size, embd_size,).to(device)
optimizer = optim.???(model.parameters(), lr=learning_rate)

losses = []

model = nn.DataParallel(model)

num_epochs = 100
for _e in tqdm(range(num_epochs)):
    epcoh_loss = 0
    for sent_idx in range(w2v_dataset._len):
        for w2v_io in w2v_dataset[sent_idx]:
            # Retrieve the inputs and outputs.
            x1, x2 = w2v_io['x']
            x1, x2 = tensor(x1).to(device), tensor(x2).to(device)
            y = autograd.Variable(tensor(w2v_io['y'], dtype=torch.float)).to(device)
            # Zero gradient.
            model.zero_grad()
            # Calculate the log probability of the context embeddings.
            logprobs = ???(x1, x2)
            # This unsqueeze thing is really a feature/bug... -_-
            loss = ???(logprobs, y.unsqueeze(0)) 
            loss.???()
            optimizer.???()
            epcoh_loss += float(loss)
    torch.save(model.state_dict(), 'skipgram_checkpoint_{}.pt'.format(_e))
    losses.append(epcoh_loss)
# Out:
#   1%|          | 1/100 [00:41<1:08:04, 41.26s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-177-35cae10f640a> in <module>
#      24             # Retrieve the inputs and outputs.
#      25             x1, x2 = w2v_io['x']
# ---> 26             x1, x2 = tensor(x1).to(device), tensor(x2).to(device)
#      27             y = autograd.Variable(tensor(w2v_io['y'], dtype=torch.float)).to(device)
#      28             # Zero gradient.
#
# KeyboardInterrupt:

# %% [markdown]
# <a id="section-3-1-5-evaluate"></a>
#
# # Evaluate the model on the skipgram task

# %%
true_positive = 0
all_data = 0
# Iterate through the test sentences. 
for sent in tokenized_text_test:
    # Extract all the CBOW contexts (X) and targets (Y)
    for w2v_io in w2v_dataset._iterator(w2v_dataset.vectorize(sent)):
        model.zero_grad()
        # Retrieve the inputs and outputs.
        x1, x2 = w2v_io['x']
        x1, x2 = tensor(x1), tensor(x2)
        y = w2v_io['y']
        _, prediction =  torch.max(model(x1, x2), 1)    
        true_positive += int(prediction) == int(y)
        all_data += 1

# %%
print('Accuracy:', true_positive/all_data)
# Out:
# Accuracy: 0.5

# %% [markdown]
# ## Download the Collobert and Weston SENNA Embeddings
#
#
# If you're on a Mac or Linux, you can use the `!` bang commands in the next cell to get the data.
#
# ```
# !pip install kaggle
# !mkdir -p .kaggle
# !echo '{"username":"natgillin","key":"54ae95ab760b52c3307ed4645c6c9b5d"}' > .kaggle/kaggle.json
# !chmod 600 .kaggle/kaggle.json
# !kaggle datasets download -d alvations/vegetables-senna-embeddings --force -p ./
# ```
#
# If you're on windows go to https://www.kaggle.com/alvations/vegetables-senna-embeddings and download the data files.
#
# What's most important are the
#  - `.txt` file that contains the vocabulary list
#  - `.npy` file that contains the binarized numpy array
#
# The rows of the numpy array corresponds to the vocabulary in the order from the `.txt` file.

# %% [markdown]
# <a id="section-3-1-6-vocab"></a>
#
#
# ## 3.1.6. Loading Pre-trained Embeddings
#
# Lets overwrite the `Word2VecText` object with the pretrained embeddings.
#
# Most important thing is the overwrite the `Dictionary` from `gensim` with the vocabulary of the pre-trained embeddings, as such:
#
# ```python
#         # Loads the pretrained keys.
#         with open('senna.wiki-reuters.lm2.50d.txt') as fin:
#             pretrained_keys = {line.strip():i for i, line in enumerate(fin)}
#         self.vocab = Dictionary({})
#         self.vocab.token2id = pretrained_keys
# ```

# %%
class Word2VecText(Dataset):
    def __init__(self, tokenized_texts, window_size, variant):
        """
        :param tokenized_texts: Tokenized text.
        :type tokenized_texts: list(list(str))
        """
        self.sents = tokenized_texts
        self._len = len(self.sents)
        
        # Loads the pretrained keys. 
        with open('senna.wiki-reuters.lm2.50d.txt') as fin:
            pretrained_keys = {line.strip():i for i, line in enumerate(fin)}
        self.vocab = Dictionary({})
        self.vocab.token2id = pretrained_keys
        
        self.window_size = window_size
        self.variant = variant
        if variant.lower() == 'cbow':
            self._iterator = partial(self.cbow_iterator, window_size=self.window_size)
        elif variant.lower() == 'skipgram':
            self._iterator = partial(self.skipgram_iterator, window_size=self.window_size)

    def __getitem__(self, index):
        """
        The primary entry point for PyTorch datasets.
        This is were you access the specific data row you want.
        
        :param index: Index to the data point.
        :type index: int
        """
        vectorized_sent = self.vectorize(self.sents[index])
        
        return list(self._iterator(vectorized_sent))

    def __len__(self):
        return self._len
    
    def vectorize(self, tokens):
        """
        :param tokens: Tokens that should be vectorized. 
        :type tokens: list(str)
        """
        # See https://radimrehurek.com/gensim/corpora/dictionary.html#gensim.corpora.dictionary.Dictionary.doc2idx 
        return self.vocab.doc2idx(tokens, unknown_word_index=-1)
    
    def unvectorize(self, indices):
        """
        :param indices: Converts the indices back to tokens.
        :type tokens: list(int)
        """
        return [self.vocab[i] for i in indices]
    
    def cbow_iterator(self, tokens, window_size):
        n = window_size * 2 + 1
        for window in per_window(tokens, n):
            target = window.pop(window_size)
            yield {'x': window, 'y': target}   # X = window ; Y = target. 
            
    def skipgram_iterator(self, tokens, window_size):
        n = window_size * 2 + 1 
        for i, window in enumerate(per_window(tokens, n)):
            focus = window.pop(window_size)
            # Generate positive samples.
            for context_word in window:
                yield {'x': (focus, context_word), 'y':1}
            # Generate negative samples.
            for _ in range(n-1):
                leftovers = tokens[:i] + tokens[i+n:]
                if leftovers:
                    yield {'x': (focus, random.choice(leftovers)), 'y':0}

# %% [markdown]
# <a id="section-3-1-6-pretrained"></a>
#
# ## Override the embeddings layer with the pre-trained weights.
#
# In PyTorch, the weights of the `nn.Embedding` object can be easily overwritten with `from_pretrained` function, see https://pytorch.org/docs/stable/nn.html#embedding

# %%
class SkipGram(nn.Module):
    def __init__(self, pretrained_npy):
        super(SkipGram, self).__init__()
        self.embeddings = nn.Embedding.from_pretrained(pretrained_npy)
    
    def forward(self, focus, context):
        # Put the index of the focus word into the embedding layer.
        embed_focus = self.???(focus).view((1, -1))
        # Put the index of the context word into the embedding layer.
        embed_context = self.???(context).view((1, -1))
        # See https://pytorch.org/docs/stable/torch.html#torch.t
        # Do a matrix multiplication between the focus and context embedding
        score = ???(embed_focus, torch.t(embed_context))
        # Then put it through a log sigmoid activation function
        # so that the output is between (log(0), log(1))
        log_probs = F.???(score)
        return log_probs

# %%
np.load('senna.wiki-reuters.lm2.50d.npy')
# Out:
# array([[-1.03682 ,  1.77856 , -0.693547, ..., -0.10278 , -0.36428 ,
#         -0.64853 ],
#        [-2.19067 ,  1.16642 , -1.91385 , ...,  0.870654, -0.33808 ,
#         -0.41957 ],
#        [ 1.16672 ,  0.811884, -0.115492, ..., -0.104843,  2.26862 ,
#          1.21729 ],
#        ...,
#        [-0.483488,  2.00359 ,  0.186266, ..., -0.114528,  1.50755 ,
#         -1.25606 ],
#        [ 0.201604,  1.15796 ,  0.888882, ..., -1.28183 ,  0.465847,
#         -1.57974 ],
#        [-0.238824,  0.443876,  0.290836, ..., -0.802705, -0.318169,
#         -1.4733  ]])

# %%
w2v_dataset = Word2VecText(tokenized_text_train, window_size=window_size, variant='skipgram')
pretrained_npy = torch.tensor(np.load('senna.wiki-reuters.lm2.50d.npy'))
pretrained_model = SkipGram(pretrained_npy)

# %% [markdown]
# <a id="section-3-1-6-eval-skipgram"></a>
# ## Test Pretrained Embeddings on the Skipgram Task

# %%
true_positive = 0
all_data = 0
# Iterate through the test sentences. 
for sent in tokenized_text_test:
    # Extract all the CBOW contexts (X) and targets (Y)
    for w2v_io in w2v_dataset._iterator(w2v_dataset.vectorize(sent)):
        pretrained_model.zero_grad()
        # Retrieve the inputs and outputs.
        x1, x2 = w2v_io['x']
        if -1 in (x1, x2): # Skip unknown words.
            continue
        x1, x2 = tensor(x1).to(device), tensor(x2).to(device)
        y = w2v_io['y']
        with torch.no_grad():
            logprobs = pretrained_model(x1, x2)
            _, prediction =  torch.max(logprobs, 1)    
        true_positive += int(prediction) == int(y)
        all_data += 1

# %%
with open('senna.wiki-reuters.lm2.50d.txt') as fin:
    pretrained_keys = {line.strip():i for i, line in enumerate(fin)}

# %%
print('Accuracy:', true_positive/all_data)
# Out:
# Accuracy: 0.4996360106770201

# %% [markdown]
# <a id="section-3-1-6-eval-cbow"></a>
# ## Test Pretrained Embeddings on the CBOW Task

# %%
class CBOW(nn.Module):
    def __init__(self, pretrained_npy, context_size, hidden_size):
        super(CBOW, self).__init__()
        vocab_size, embd_size = list(pretrained_npy.shape)
        self.embeddings = nn.Embedding.from_pretrained(pretrained_npy)
        self.linear1 = nn.Linear(2*context_size*embd_size, hidden_size)
        self.linear2 = nn.Linear(hidden_size, vocab_size)
        
    def forward(self, inputs):
        embedded = self.embeddings(inputs).float().view((1, -1))
        hid = F.relu(self.linear1(embedded))
        out = self.linear2(hid)
        log_probs = F.log_softmax(out, dim=1)
        return log_probs

# %%
window_size = 5
w2v_dataset = Word2VecText(tokenized_text_train, window_size=window_size, variant='cbow')
hidden_size = 300
pretrained_cbow_model = CBOW(pretrained_npy, window_size, hidden_size)

# %%
true_positive = 0
all_data = 0
# Iterate through the test sentences. 
for sent in tokenized_text_test:
    # Extract all the CBOW contexts (X) and targets (Y)
    for w2v_io in w2v_dataset._iterator(w2v_dataset.vectorize(sent)):
        # Retrieve the inputs and outputs.
        x = tensor(w2v_io['x']).to(device)
        y = tensor(w2v_io['y']).to(device)
        
        if -1 in x: # Skip unknown words.
            continue
        with torch.no_grad():
            _, prediction =  torch.max(pretrained_cbow_model(x), 1)
        true_positive += int(prediction) == int(y)
        visualize_predictions(x, y, prediction, w2v_dataset.vocab, window_size=window_size)
        all_data += 1
# Out:
# : 		 the problem is essentially this victorino if a word ( or
# re- 		 the web is a vast venetians source for many languages .
# random 		 is that the association is bhim , arbitrary , motivated or
# , 		 that the association is random co-ordinate arbitrary , motivated or pre-
# <unk> 		 arbitrary , motivated or pre- masovian ( r , a ,
# inevitably 	 however , their methods are recolored noisy , suffering , for
# noisy 		 , their methods are inevitably mid-columbia , suffering , for example
# , 		 their methods are inevitably noisy jailbreak suffering , for example ,
# suffering 	 methods are inevitably noisy , scheepbouwer , for example , from
# , 		 are inevitably noisy , suffering landrum for example , from just
# for 		 inevitably noisy , suffering , operatives example , from just those
# example 	 noisy , suffering , for orihime , from just those parser
# , 		 , suffering , for example mid-way from just those parser errors
# from 		 suffering , for example , wars just those parser errors that
# just 		 , for example , from ocracoke those parser errors that the
# those 		 for example , from just obayashi parser errors that the whole
# parser 		 example , from just those unsurprising errors that the whole process
# errors 		 , from just those parser sonthi that the whole process is
# that 		 from just those parser errors dmd the whole process is designed
# the 		 just those parser errors that travelling whole process is designed to
# whole 		 those parser errors that the premonstratensian process is designed to address
# process 	 parser errors that the whole lobo is designed to address ,
# is 		 errors that the whole process handle designed to address , and
# designed 	 that the whole process is lammas to address , and they
# to 		 the whole process is designed well-below address , and they do
# address 	 whole process is designed to zarb , and they do not
# , 		 process is designed to address secularised and they do not wish
# and 		 is designed to address , genl they do not wish to
# they 		 designed to address , and unsurprising do not wish to accept
# do 		 to address , and they o'rahilly not wish to accept any
# not 		 address , and they do moro wish to accept any scf
# wish 		 , and they do not pontchartrain to accept any scf for
# to 		 and they do not wish midd accept any scf for which
# accept 		 they do not wish to palus any scf for which there
# any 		 do not wish to accept grose scf for which there is
# scf 		 not wish to accept any dorking for which there is any
# for 		 wish to accept any scf ladbroke which there is any evidence
# which 		 to accept any scf for striding there is any evidence as
# there 		 accept any scf for which quiz is any evidence as a
# is 		 any scf for which there fahrenheit any evidence as a true
# any 		 scf for which there is teekay evidence as a true scf
# evidence 	 for which there is any january-november as a true scf for
# as 		 which there is any evidence collaborates a true scf for the
# a 		 there is any evidence as uav true scf for the verb
# true 		 is any evidence as a wosz scf for the verb .
# that 		 while it might seem plausible pontchartrain oddities would in some way
# oddities 	 it might seem plausible that fungurume would in some way balance
# would 		 might seem plausible that oddities sampoerna in some way balance out
# in 		 seem plausible that oddities would lavera some way balance out to
# some 		 plausible that oddities would in stover way balance out to give
# way 		 that oddities would in some zheng balance out to give a
# <unk> 		 balance out to give a blick tion that was indistinguishable from
# one 		 tion that was indistinguishable from piasecki where the individual words (
# where 		 that was indistinguishable from one welt the individual words ( as
# the 		 was indistinguishable from one where valenti individual words ( as opposed
# individual 	 indistinguishable from one where the electricians words ( as opposed to
# words 		 from one where the individual bartram ( as opposed to the
# ( 		 one where the individual words pager as opposed to the texts
# as 		 where the individual words ( conall opposed to the texts )
# opposed 	 the individual words ( as tok'ra to the texts ) had
# to 		 individual words ( as opposed teekay the texts ) had been
# the 		 words ( as opposed to blick texts ) had been randomly
# texts 		 ( as opposed to the arche ) had been randomly selected
# ) 		 as opposed to the texts polygons had been randomly selected ,
# had 		 opposed to the texts ) agitator been randomly selected , this
# been 		 to the texts ) had emv randomly selected , this turns
# randomly 	 the texts ) had been chartres selected , this turns out
# selected 	 texts ) had been randomly barenboim , this turns out not
# , 		 ) had been randomly selected kreuzer this turns out not to
# this 		 had been randomly selected , bild turns out not to be
# turns 		 been randomly selected , this romance out not to be the
# out 		 randomly selected , this turns php0 not to be the case
# not 		 selected , this turns out rekindle to be the case .
# varies 		 however where the sample size victorias by an order of magnitude
# by 		 where the sample size varies governing an order of magnitude ,
# an 		 the sample size varies by lammas order of magnitude , or
# order 		 sample size varies by an staats of magnitude , or where
# of 		 size varies by an order predecessor magnitude , or where it
# magnitude 	 varies by an order of salm , or where it is
# , 		 by an order of magnitude invested or where it is enormous
# or 		 an order of magnitude , hibiscus where it is enormous ,
# where 		 order of magnitude , or woo-suk it is enormous , it
# it 		 of magnitude , or where shipp is enormous , it is
# is 		 magnitude , or where it three-mile enormous , it is wrong
# enormous 	 , or where it is al-bayan , it is wrong to
# , 		 or where it is enormous unsurprising it is wrong to identify
# it 		 where it is enormous , wittman is wrong to identify the
# the 		 proceedings of the conference of bookrunner south-central sas users group ,
# an 		 making false assumptions is often mappings ingenious way to proceed ;
# ingenious 	 false assumptions is often an despatched way to proceed ; the
# way 		 assumptions is often an ingenious 'how to proceed ; the problem
# to 		 is often an ingenious way rimantas proceed ; the problem arises
# proceed 	 often an ingenious way to atoll ; the problem arises where
# ; 		 an ingenious way to proceed bunzl the problem arises where the
# the 		 ingenious way to proceed ; thuringowa problem arises where the literal
# problem 	 way to proceed ; the tok'ra arises where the literal falsity
# arises 		 to proceed ; the problem mystere where the literal falsity of
# where 		 proceed ; the problem arises entangle the literal falsity of the
# the 		 ; the problem arises where grauman literal falsity of the assumption
# literal 	 the problem arises where the tok'ra falsity of the assumption is
# falsity 	 problem arises where the literal meow of the assumption is overlooked
# of 		 arises where the literal falsity reigning the assumption is overlooked ,
# the 		 where the literal falsity of vltava assumption is overlooked , and
# <unk> 		 assumption is overlooked , and palestinans ate inferences are drawn .
# <unk> 		 when we look at linguistic unsurprising ena in corpora , the
# null 		 ena in corpora , the nussbaum hypothesis will never be true
# hypothesis 	 in corpora , the null teamed will never be true .
# enough 		 we do not always have pensioners data to reject the null
# data 		 do not always have enough mearns to reject the null hypothesis
# to 		 not always have enough data 'dirty reject the null hypothesis ,
# reject 		 always have enough data to gesury the null hypothesis , but
# the 		 have enough data to reject fidonet null hypothesis , but that
# null 		 enough data to reject the babenberg hypothesis , but that is
# hypothesis 	 data to reject the null recolored , but that is a
# , 		 to reject the null hypothesis oba but that is a distinct
# but 		 reject the null hypothesis , distrustful that is a distinct issue
# that 		 the null hypothesis , but maroc is a distinct issue :
# is 		 null hypothesis , but that binaural a distinct issue : wherever
# a 		 hypothesis , but that is euromerchant distinct issue : wherever there
# distinct 	 , but that is a malkin issue : wherever there is
# issue 		 but that is a distinct belated : wherever there is enough
# : 		 that is a distinct issue seagram wherever there is enough data
# wherever 	 is a distinct issue : soir there is enough data ,
# there 		 a distinct issue : wherever withered is enough data , it
# is 		 distinct issue : wherever there avestan enough data , it is
# enough 		 issue : wherever there is succumbs data , it is rejected
# data 		 : wherever there is enough emesa , it is rejected .
# are 		 since words in a text piasecki not random , we know
# not 		 words in a text are physiognomy random , we know that
# random 		 in a text are not criticised , we know that our
# , 		 a text are not random operatives we know that our corpora
# we 		 text are not random , dn# know that our corpora are
# know 		 are not random , we quiz that our corpora are not
# that 		 not random , we know kreuzer our corpora are not randomly
# our 		 random , we know that motorcades corpora are not randomly generated
# corpora 	 , we know that our aktuelt are not randomly generated ,
# are 		 we know that our corpora mueang not randomly generated , and
# not 		 know that our corpora are wattoo randomly generated , and the
# randomly 	 that our corpora are not eraiba generated , and the hypothesis
# generated 	 our corpora are not randomly jew , and the hypothesis test
# the 		 gives us reason to view coulthard relation between , for example
# relation 	 us reason to view the londinium between , for example ,
# between 	 reason to view the relation wral , for example , a
# , 		 to view the relation between workup for example , a verb
# <unk> 		 for example , a verb newmar s syntax and its semantics
# , 		 s syntax and its semantics mmbg as motivated rather than arbitrary
# as 		 syntax and its semantics , locative motivated rather than arbitrary .
# error 		 the average value of the drastically term , language is never
# term 		 average value of the error ullevi , language is never ,
# , 		 value of the error term blick language is never , ever
# language 	 of the error term , recolored is never , ever ,
# is 		 the error term , language blick never , ever , ever
# never 		 error term , language is maru , ever , ever ,
# , 		 term , language is never antananarivo ever , ever , random
# , 		 the hypothesis can , therefore steamship be couched as : are
# be 		 hypothesis can , therefore , solder couched as : are the
# couched 	 can , therefore , be lammas as : are the error
# as 		 , therefore , be couched ---- : are the error terms
# : 		 therefore , be couched as cos0 are the error terms systematically
# are 		 , be couched as : reflex the error terms systematically greater
# the 		 be couched as : are moro error terms systematically greater than
# becomes 	 % of them , devastate itsekiri one of the verbs for
# one 		 of them , devastate becomes teekay of the verbs for which
# of 		 them , devastate becomes one recolored the verbs for which we
# the 		 , devastate becomes one of interplanetary verbs for which we have
# verbs 		 devastate becomes one of the hankook for which we have plenty
# for 		 becomes one of the verbs mosenergo which we have plenty of
# which 		 one of the verbs for stover we have plenty of data
# we 		 of the verbs for which narbonensis have plenty of data ,
# have 		 the verbs for which we bloch plenty of data , and
# plenty 		 verbs for which we have solti of data , and crude

# %%
print('Accuracy:', true_positive/all_data)
# Out:
# Accuracy: 0.0

# %% [markdown]
# <a id="section-3-1-6-unfreeze-finetune"></a>
# ## Unfreeze the Embedddings and Tune it on the CBOW Task

# %%
class CBOW(nn.Module):
    def __init__(self, pretrained_npy, context_size, hidden_size):
        super(CBOW, self).__init__()
        vocab_size, embd_size = list(pretrained_npy.shape)
        # See https://pytorch.org/docs/stable/nn.html#torch.nn.Embedding.from_pretrained
        # Note the `freeze=False`, by default if you use `nn.Embedding.from_pretrained(),
        # `freeze` is set to True
        self.embeddings = nn.Embedding.from_pretrained(pretrained_npy, freeze=False)
        self.linear1 = nn.Linear(2*context_size*embd_size, hidden_size)
        self.linear2 = nn.Linear(hidden_size, vocab_size)
        
    def forward(self, inputs):
        embedded = self.embeddings(inputs).float().view((1, -1))
        hid = F.relu(self.linear1(embedded))
        out = self.linear2(hid)
        log_probs = F.log_softmax(out, dim=1)
        return log_probs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a461e43c6728> in <module>
# ----> 1 class CBOW(nn.Module):
#       2     def __init__(self, pretrained_npy, context_size, hidden_size):
#       3         super(CBOW, self).__init__()
#       4         vocab_size, embd_size = list(pretrained_npy.shape)
#       5         # See https://pytorch.org/docs/stable/nn.html#torch.nn.Embedding.from_pretrained
#
# NameError: name 'nn' is not defined

# %%
window_size = 2 
w2v_dataset = Word2VecText(tokenized_text_train, window_size=window_size, variant='cbow')
hidden_size = 300
pretrained_cbow_model = CBOW(pretrained_npy, window_size, hidden_size)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-985992808650> in <module>
#       1 window_size = 2
# ----> 2 w2v_dataset = Word2VecText(tokenized_text_train, window_size=window_size, variant='cbow')
#       3 hidden_size = 300
#       4 pretrained_cbow_model = CBOW(pretrained_npy, window_size, hidden_size)
#
# NameError: name 'Word2VecText' is not defined

# %%
learning_rate = 0.003
criterion = nn.NLLLoss()
optimizer = optim.SGD(pretrained_cbow_model.parameters(), lr=learning_rate)

losses = []

model = nn.DataParallel(pretrained_cbow_model)

num_epochs = 100
for _e in tqdm(range(num_epochs)):
    epoch_loss = []
    for sent_idx in range(w2v_dataset._len):
        for w2v_io in w2v_dataset[sent_idx]:
            # Retrieve the inputs and outputs.
            x = tensor(w2v_io['x']).to(device)
            y = autograd.Variable(tensor(w2v_io['y'], dtype=torch.long)).to(device)
            
            if -1 in x or int(y) == -1:
                continue
            # Zero gradient.
            model.zero_grad()
            # Calculate the log probability of the context embeddings.
            logprobs = pretrained_cbow_model(x)
            # This unsqueeze thing is really a feature/bug... -_-
            loss = criterion(logprobs, y.unsqueeze(0)) 
            loss.backward()
            optimizer.step()
            epoch_loss.append(float(loss))
    # Save model after every epoch.
    torch.save(model.state_dict(), 'cbow_finetuning_checkpoint_{}.pt'.format(_e))
    losses.append(sum(epoch_loss)/len(epoch_loss))
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-194-4f84802592bd> in <module>
#      24             # This unsqueeze thing is really a feature/bug... -_-
#      25             loss = criterion(logprobs, y.unsqueeze(0))
# ---> 26             loss.backward()
#      27             optimizer.step()
#      28             epoch_loss.append(float(loss))
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     100                 products. Defaults to ``False``.
#     101         """
# --> 102         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     103
#     104     def register_hook(self, hook):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      88     Variable._execution_engine.run_backward(
#      89         tensors, grad_tensors, retain_graph, create_graph,
# ---> 90         allow_unreachable=True)  # allow_unreachable flag
#      91
#      92
#
# KeyboardInterrupt:

# %% [markdown]
# <a id="section-3-1-6-reval-cbow"></a>
#
# ## Re-Test Pretrained Embeddings on the CBOW Task

# %%
true_positive = 0
all_data = 0
# Iterate through the test sentences. 
for sent in tokenized_text_test:
    # Extract all the CBOW contexts (X) and targets (Y)
    for w2v_io in w2v_dataset._iterator(w2v_dataset.vectorize(sent)):
        # Retrieve the inputs and outputs.
        x = tensor(w2v_io['x']).to(device)
        y = tensor(w2v_io['y']).to(device)
        
        if -1 in x: # Skip unknown words.
            continue
        with torch.no_grad():
            _, prediction =  torch.max(pretrained_cbow_model(x), 1)
        true_positive += int(prediction) == int(y)
        visualize_predictions(x, y, prediction, w2v_dataset.vocab, window_size=window_size)
        all_data += 1

# %%
print('Accuracy:', true_positive/all_data)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-117-a1fbc309b646> in <module>
# ----> 1 print('Accuracy:', true_positive/all_data)
#
# ZeroDivisionError: division by zero
